# %% [markdown]
# # Basic Models in Tensorflow

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /Users/thchang/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Linear Regression using Dummy Data
# We're going to build a simple linear regression model that learns a function between 1d input and 1d output.
#
# This means for scalar input $X$ and scalar output $Y$, we learn a function the weights of the function $f(x)$
#
# $$f(X) = w * X + b$$ where we learn $w, b$
#
# We're going to use a dummy dataset for ease. We load the csv in the next cell

# %%
df = pd.read_csv("linreg.csv", header = None)

# %%
display(df.head())
# Out:
#     0          1
# 0  24  21.549452
# 1  50  47.464463
# 2  15  17.218656
# 3  38  36.586398
# 4  87  87.288984

# %% [markdown]
# Create a placeholder value for the feature X and the output y. Both X and y should be float scalars represented by tf.float32. The placeholders set the type and shape of input. By default, placeholders are scalars.

# %%
#TODO: Fill in the dots
X = tf.placeholder(tf.float32, name='X')#, shape=[None, 1])
y = tf.placeholder(tf.float32, name='y')#, shape=[None, 1])

# %% [markdown]
# Create a variable for the weight, $w$, and another for the bias, $b$. Both can initially be set to a small number such as 0.1. These will be the values we update in training.

# %%
#TODO: Fill in the dots
w = tf.Variable(0.1)
b = tf.Variable(0.1)

# %% [markdown]
# We simply compute the predicted value of y using $\hat{y}  = w * X + b$

# %%
y_pred = tf.add(tf.multiply(w, X), b) 
# We could have also written w* X + b but using tf methods can make the operation more clear.

# %% [markdown]
# Compute the loss. We're using Mean Squared Error for our  loss function, $$\mathcal{L}_{MSE} = (y - \hat{y})^2$$

# %%
#TODO: Fill in the dots
loss = tf.square( y - y_pred, name='loss')

# %% [markdown]
# ### Other loss functions: ###
#     - tf.nn.softmax_cross_entropy_with_logits
#     -

# %% [markdown]
# ## Optimizer
# The optimizer powers our algorithm's learning abilities. The optimizer performs gradient descent on the loss function, and adjusts all of the variables in order to decrease the loss.
#
# We will use the simplest optimizer, GradientDescentOptimizer, with an appropriate learning rate. Set it to minimize the loss.

# %%
#TODO: Fill in the dots
optimizer = tf.train.GradientDescentOptimizer(learning_rate= 0.4).minimize(loss)

# %% [markdown]
# # Training
# * For each epoch, run the optimizer on each X,y pair (each batch) from the dataset and sum up the loss over all data points
# * Print the loss after each epoch (full iteration through dataset)
# * Get the final values of the weights and the bias

# %%
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())
for i in range(5):
    total_loss = 0
    for row in df.values:
        x_batch = row[0]
        y_batch = row[1]

        print("x_batch={} y_batch={}".format(x_batch, y_batch))
        _, l = sess.run([optimizer, loss], feed_dict={X: x_batch, y: y_batch})
        total_loss += l
    # Print the loss after each epoch ()
    print("Epoch {0}: {1}".format(i, total_loss))
# Get the final values of the weights and the bias 
weight, bias = sess.run([w, b])
# Out:
# x_batch=24.0 y_batch=21.54945196
# x_batch=50.0 y_batch=47.46446305
# x_batch=15.0 y_batch=17.21865634
# x_batch=38.0 y_batch=36.58639803
# x_batch=87.0 y_batch=87.28898389
# x_batch=36.0 y_batch=32.46387493
# x_batch=12.0 y_batch=10.78089683
# x_batch=81.0 y_batch=80.7633986
# x_batch=25.0 y_batch=24.61215147
# x_batch=5.0 y_batch=6.963319071
# x_batch=16.0 y_batch=11.23757338
# x_batch=16.0 y_batch=13.53290206
# x_batch=24.0 y_batch=24.60323899
# x_batch=39.0 y_batch=39.40049976
# x_batch=54.0 y_batch=48.43753838
# x_batch=60.0 y_batch=61.69900319
# x_batch=26.0 y_batch=26.92832418
# x_batch=73.0 y_batch=70.4052055
# x_batch=29.0 y_batch=29.34092408
# x_batch=31.0 y_batch=25.30895192
# x_batch=68.0 y_batch=69.02934339
# x_batch=87.0 y_batch=84.99484703
# x_batch=58.0 y_batch=57.04310305
# x_batch=54.0 y_batch=50.5921991
# x_batch=84.0 y_batch=83.02772202
# x_batch=58.0 y_batch=57.05752706
# x_batch=49.0 y_batch=47.95883341
# x_batch=20.0 y_batch=24.34226432
# x_batch=90.0 y_batch=94.68488281
# x_batch=48.0 y_batch=48.03970696
# x_batch=4.0 y_batch=7.08132338
# x_batch=25.0 y_batch=21.99239907
# x_batch=42.0 y_batch=42.33151664
# x_batch=0.0 y_batch=0.329089443
# x_batch=60.0 y_batch=61.92303698
# x_batch=93.0 y_batch=91.17716423
# x_batch=39.0 y_batch=39.45358014
# x_batch=7.0 y_batch=5.996069607
# x_batch=21.0 y_batch=22.59015942
# x_batch=68.0 y_batch=61.18044414
# x_batch=84.0 y_batch=85.02778957
# x_batch=0.0 y_batch=-1.28631089
# x_batch=58.0 y_batch=61.94273962
# x_batch=19.0 y_batch=21.96033347
# x_batch=36.0 y_batch=33.66194193
# x_batch=19.0 y_batch=17.60946242
# x_batch=59.0 y_batch=58.5630564
# x_batch=51.0 y_batch=52.82390762
# x_batch=19.0 y_batch=22.1363481
# x_batch=33.0 y_batch=35.07467353
# x_batch=85.0 y_batch=86.18822311
# x_batch=44.0 y_batch=42.63227697
# x_batch=5.0 y_batch=4.09817744
# x_batch=59.0 y_batch=61.2229864
# x_batch=14.0 y_batch=17.70677576
# x_batch=9.0 y_batch=11.85312574
# x_batch=75.0 y_batch=80.23051695
# x_batch=69.0 y_batch=62.64931741
# x_batch=10.0 y_batch=9.616859804
# x_batch=17.0 y_batch=20.02797699
# x_batch=58.0 y_batch=61.7510743
# x_batch=74.0 y_batch=71.61010303
# x_batch=21.0 y_batch=23.77154623
# x_batch=51.0 y_batch=51.90142035
# x_batch=19.0 y_batch=22.66073682
# x_batch=50.0 y_batch=50.02897927
# x_batch=24.0 y_batch=26.68794368
# x_batch=0.0 y_batch=0.376911899
# x_batch=12.0 y_batch=6.806419002
# x_batch=75.0 y_batch=77.33986001
# x_batch=21.0 y_batch=28.90260209
# x_batch=64.0 y_batch=66.7346608
# x_batch=5.0 y_batch=0.707510638
# x_batch=58.0 y_batch=57.07748383
# x_batch=32.0 y_batch=28.41453196
# x_batch=41.0 y_batch=44.46272123
# x_batch=7.0 y_batch=7.459605998
# x_batch=4.0 y_batch=2.316708112
# x_batch=5.0 y_batch=4.928546187
# x_batch=49.0 y_batch=52.50336074
# x_batch=90.0 y_batch=91.19109623
# x_batch=3.0 y_batch=8.489164326
# x_batch=11.0 y_batch=6.963371967
# x_batch=32.0 y_batch=31.97989959
# x_batch=83.0 y_batch=81.4281205
# x_batch=25.0 y_batch=22.62365422
# x_batch=83.0 y_batch=78.52505087
# x_batch=26.0 y_batch=25.80714057
# x_batch=76.0 y_batch=73.51081775
# x_batch=95.0 y_batch=91.775467
# x_batch=53.0 y_batch=49.21863516
# x_batch=77.0 y_batch=80.50445387
# x_batch=42.0 y_batch=50.05636123
# x_batch=25.0 y_batch=25.46292549
# x_batch=54.0 y_batch=55.32164264
# x_batch=55.0 y_batch=59.1244888
# x_batch=0.0 y_batch=1.100686692
# x_batch=73.0 y_batch=71.98020786
# x_batch=35.0 y_batch=30.13666408
# x_batch=86.0 y_batch=83.88427405
# x_batch=90.0 y_batch=89.91004752
# x_batch=13.0 y_batch=8.335654576
# x_batch=46.0 y_batch=47.88388961
# x_batch=46.0 y_batch=45.00397413
# x_batch=32.0 y_batch=31.15664574
# x_batch=8.0 y_batch=9.190375682
# x_batch=71.0 y_batch=74.83135003
# x_batch=28.0 y_batch=30.23177607
# x_batch=24.0 y_batch=24.21914027
# x_batch=56.0 y_batch=57.87219151
# x_batch=49.0 y_batch=50.61728392
# x_batch=79.0 y_batch=78.67470043
# x_batch=90.0 y_batch=86.236707
# x_batch=89.0 y_batch=89.10409255
# x_batch=41.0 y_batch=43.26595082
# x_batch=27.0 y_batch=26.68273277
# x_batch=58.0 y_batch=59.46383041
# x_batch=26.0 y_batch=28.90055826
# x_batch=31.0 y_batch=31.300416
# x_batch=70.0 y_batch=71.1433266
# x_batch=71.0 y_batch=68.4739206
# x_batch=39.0 y_batch=39.98238856
# x_batch=7.0 y_batch=4.075776144
# x_batch=48.0 y_batch=47.85817542
# x_batch=56.0 y_batch=51.20390217
# x_batch=45.0 y_batch=43.9367213
# x_batch=41.0 y_batch=38.13626679
# x_batch=3.0 y_batch=3.574661632
# x_batch=37.0 y_batch=36.4139958
# x_batch=24.0 y_batch=22.21908523
# x_batch=68.0 y_batch=63.5312572
# x_batch=47.0 y_batch=49.86702787
# x_batch=27.0 y_batch=21.53140009
# x_batch=68.0 y_batch=64.05710234
# x_batch=74.0 y_batch=70.77549842
# x_batch=95.0 y_batch=92.15749762
# x_batch=79.0 y_batch=81.22259156
# x_batch=21.0 y_batch=25.10114067
# x_batch=95.0 y_batch=94.08853397
# x_batch=54.0 y_batch=53.25166165
# x_batch=56.0 y_batch=59.16236621
# x_batch=80.0 y_batch=75.24148428
# x_batch=26.0 y_batch=28.22325833
# x_batch=25.0 y_batch=25.33323728
# x_batch=8.0 y_batch=6.364615703
# x_batch=95.0 y_batch=95.4609216
# x_batch=94.0 y_batch=88.64183756
# x_batch=54.0 y_batch=58.70318693
# x_batch=7.0 y_batch=6.815491279
# x_batch=99.0 y_batch=99.40394676
# x_batch=36.0 y_batch=32.77049249
# x_batch=48.0 y_batch=47.0586788
# x_batch=65.0 y_batch=60.53321778
# x_batch=42.0 y_batch=40.30929858
# x_batch=93.0 y_batch=89.42222685
# x_batch=86.0 y_batch=86.82132066
# x_batch=26.0 y_batch=26.11697543
# x_batch=51.0 y_batch=53.26657596
# x_batch=100.0 y_batch=96.62327888
# x_batch=94.0 y_batch=95.78441027
# x_batch=6.0 y_batch=6.047286687
# x_batch=24.0 y_batch=24.47387908
# x_batch=75.0 y_batch=75.96844763
# x_batch=7.0 y_batch=3.829381009
# x_batch=53.0 y_batch=52.51703683
# x_batch=73.0 y_batch=72.80457527
# x_batch=16.0 y_batch=14.10999096
# x_batch=80.0 y_batch=80.86087062
# x_batch=77.0 y_batch=77.01988215
# x_batch=89.0 y_batch=86.26972444
# x_batch=80.0 y_batch=77.13735466
# x_batch=55.0 y_batch=51.47649476
# x_batch=19.0 y_batch=17.34557531
# x_batch=56.0 y_batch=57.72853572
# x_batch=47.0 y_batch=44.15029394
# x_batch=56.0 y_batch=59.24362743
# x_batch=2.0 y_batch=-1.053275611
# x_batch=82.0 y_batch=86.79002254
# x_batch=57.0 y_batch=60.14031858
# x_batch=44.0 y_batch=44.04222058
# x_batch=26.0 y_batch=24.5227488
# x_batch=52.0 y_batch=52.95305521
# x_batch=41.0 y_batch=43.16133498
# x_batch=44.0 y_batch=45.67562576
# x_batch=3.0 y_batch=-2.830749501
# x_batch=31.0 y_batch=29.19693178
# x_batch=97.0 y_batch=96.49812401
# x_batch=21.0 y_batch=22.5453232
# x_batch=17.0 y_batch=20.10741433
# x_batch=7.0 y_batch=4.035430253
# x_batch=61.0 y_batch=61.14568518
# x_batch=10.0 y_batch=13.97163653
# x_batch=52.0 y_batch=55.34529893
# x_batch=10.0 y_batch=12.18441166
# x_batch=65.0 y_batch=64.00077658
# x_batch=71.0 y_batch=70.3188322
# x_batch=4.0 y_batch=-0.936895047
# x_batch=24.0 y_batch=18.91422276
# x_batch=26.0 y_batch=23.87590331
# x_batch=51.0 y_batch=47.5775361
# x_batch=42.0 y_batch=43.2736092
# x_batch=62.0 y_batch=66.48278755
# x_batch=74.0 y_batch=75.72605529
# x_batch=77.0 y_batch=80.59643338
# x_batch=3.0 y_batch=-2.235879852
# x_batch=50.0 y_batch=47.04654956
# x_batch=24.0 y_batch=21.59635575
# x_batch=37.0 y_batch=32.87558963
# x_batch=58.0 y_batch=57.95782956
# x_batch=52.0 y_batch=52.24760027
# x_batch=27.0 y_batch=24.58286902
# x_batch=14.0 y_batch=12.12573805
# x_batch=100.0 y_batch=100.0158026
# x_batch=72.0 y_batch=74.04682658
# x_batch=5.0 y_batch=1.611947467
# x_batch=71.0 y_batch=70.36836307
# x_batch=54.0 y_batch=52.26831735
# x_batch=84.0 y_batch=83.1286166
# x_batch=42.0 y_batch=43.64765048
# x_batch=54.0 y_batch=49.44785426
# x_batch=74.0 y_batch=72.6356699
# x_batch=54.0 y_batch=52.78130641
# x_batch=53.0 y_batch=57.11195136
# x_batch=78.0 y_batch=79.1050629
# x_batch=97.0 y_batch=101.6228548
# x_batch=49.0 y_batch=53.5825402
# x_batch=71.0 y_batch=68.92139297
# x_batch=48.0 y_batch=46.9666961
# x_batch=51.0 y_batch=51.02642868
# x_batch=89.0 y_batch=85.52073551
# x_batch=99.0 y_batch=99.51685756
# x_batch=93.0 y_batch=94.63911256
# x_batch=49.0 y_batch=46.78357742
# x_batch=18.0 y_batch=21.21321959
# x_batch=65.0 y_batch=58.37266004
# x_batch=83.0 y_batch=87.22059677
# x_batch=100.0 y_batch=102.4967859
# x_batch=41.0 y_batch=43.88314335
# x_batch=52.0 y_batch=53.06655757
# x_batch=29.0 y_batch=26.33464785
# x_batch=97.0 y_batch=98.52008934
# x_batch=7.0 y_batch=9.400497579
# x_batch=51.0 y_batch=52.94026699
# x_batch=58.0 y_batch=53.83020877
# x_batch=50.0 y_batch=45.94511142
# x_batch=67.0 y_batch=65.0132736
# x_batch=89.0 y_batch=86.5069584
# x_batch=76.0 y_batch=75.63280796
# x_batch=35.0 y_batch=36.78035027
# x_batch=99.0 y_batch=100.5328916
# x_batch=31.0 y_batch=29.04466136
# x_batch=52.0 y_batch=51.70352433
# x_batch=11.0 y_batch=9.199954718
# x_batch=66.0 y_batch=71.70015848
# x_batch=50.0 y_batch=49.82634062
# x_batch=39.0 y_batch=37.49971096
# x_batch=60.0 y_batch=53.65084683
# x_batch=35.0 y_batch=33.92561965
# x_batch=53.0 y_batch=49.92639685
# x_batch=14.0 y_batch=8.148154262
# x_batch=49.0 y_batch=49.72359037
# x_batch=16.0 y_batch=16.16712757
# x_batch=76.0 y_batch=75.30033002
# x_batch=13.0 y_batch=9.577368568
# x_batch=51.0 y_batch=48.38088357
# x_batch=70.0 y_batch=72.95331671
# x_batch=98.0 y_batch=92.59573853
# x_batch=86.0 y_batch=88.85523586
# x_batch=100.0 y_batch=99.00361771
# x_batch=46.0 y_batch=45.09439571
# x_batch=51.0 y_batch=46.94362684
# x_batch=50.0 y_batch=48.33449605
# x_batch=91.0 y_batch=94.92329574
# x_batch=48.0 y_batch=47.78165248
# x_batch=81.0 y_batch=81.28960746
# x_batch=38.0 y_batch=37.83155021
# x_batch=40.0 y_batch=39.69185252
# x_batch=79.0 y_batch=76.92664854
# x_batch=96.0 y_batch=88.02990531
# x_batch=60.0 y_batch=56.99178872
# x_batch=70.0 y_batch=72.58929383
# x_batch=44.0 y_batch=44.98103442
# x_batch=11.0 y_batch=11.99017641
# x_batch=6.0 y_batch=1.919513328
# x_batch=5.0 y_batch=1.628826073
# x_batch=72.0 y_batch=66.27746655
# x_batch=55.0 y_batch=57.53887255
# x_batch=95.0 y_batch=94.70291077
# x_batch=41.0 y_batch=41.21469904
# x_batch=25.0 y_batch=25.04169243
# x_batch=1.0 y_batch=3.778209914
# x_batch=55.0 y_batch=50.50711779
# x_batch=4.0 y_batch=9.682408486
# x_batch=48.0 y_batch=48.88147608
# x_batch=55.0 y_batch=54.40348599
# x_batch=75.0 y_batch=71.70233156
# x_batch=68.0 y_batch=69.35848388
# x_batch=100.0 y_batch=99.98491591
# x_batch=25.0 y_batch=26.03323718
# x_batch=75.0 y_batch=75.48910307
# x_batch=34.0 y_batch=36.59623056
# x_batch=38.0 y_batch=40.95102191
# x_batch=92.0 y_batch=86.78316267
# x_batch=21.0 y_batch=15.50701184
# x_batch=88.0 y_batch=85.86077871
# x_batch=75.0 y_batch=79.20610113
# x_batch=76.0 y_batch=80.80643766
# x_batch=44.0 y_batch=48.59717283
# x_batch=10.0 y_batch=13.93415049
# x_batch=21.0 y_batch=27.3051179
# x_batch=16.0 y_batch=14.00226297
# x_batch=32.0 y_batch=33.67416
# x_batch=13.0 y_batch=13.11612884
# x_batch=26.0 y_batch=24.76649193
# x_batch=70.0 y_batch=73.68477876
# x_batch=77.0 y_batch=77.53149541
# x_batch=77.0 y_batch=76.24503196
# x_batch=88.0 y_batch=88.0578931
# x_batch=35.0 y_batch=35.02445799
# x_batch=24.0 y_batch=21.65857739
# x_batch=17.0 y_batch=17.33681562
# x_batch=91.0 y_batch=94.36778957
# x_batch=32.0 y_batch=33.43396307
# x_batch=36.0 y_batch=32.52179399
# x_batch=89.0 y_batch=90.57741298
# x_batch=69.0 y_batch=71.25634126
# x_batch=30.0 y_batch=31.23212856
# x_batch=6.0 y_batch=5.398840061
# x_batch=22.0 y_batch=18.56241391
# x_batch=67.0 y_batch=71.97121038
# x_batch=9.0 y_batch=5.225759566
# x_batch=74.0 y_batch=73.5964342
# x_batch=50.0 y_batch=49.76948983
# x_batch=85.0 y_batch=82.69087513
# x_batch=3.0 y_batch=1.652309089
# x_batch=0.0 y_batch=-3.836652144
# x_batch=59.0 y_batch=62.03811556
# x_batch=62.0 y_batch=61.26514581
# x_batch=17.0 y_batch=13.24991628
# x_batch=90.0 y_batch=88.61672694
# x_batch=23.0 y_batch=21.13655528
# x_batch=19.0 y_batch=23.85017475
# x_batch=93.0 y_batch=92.01203405
# x_batch=14.0 y_batch=10.26712261
# x_batch=58.0 y_batch=54.14681616
# x_batch=87.0 y_batch=87.00645713
# x_batch=37.0 y_batch=37.69447352
# x_batch=20.0 y_batch=19.62278654
# x_batch=35.0 y_batch=34.78561007
# x_batch=63.0 y_batch=62.03190983
# x_batch=56.0 y_batch=52.67003801
# x_batch=62.0 y_batch=58.09031476
# x_batch=98.0 y_batch=97.19448821
# x_batch=90.0 y_batch=90.50155298
# x_batch=51.0 y_batch=50.5123462
# x_batch=93.0 y_batch=94.45211871
# x_batch=22.0 y_batch=21.10794636
# x_batch=38.0 y_batch=37.36298431
# x_batch=13.0 y_batch=10.28574844
# x_batch=98.0 y_batch=96.04932416
# x_batch=99.0 y_batch=100.0953697
# x_batch=31.0 y_batch=30.6063167
# x_batch=94.0 y_batch=96.19000542
# x_batch=73.0 y_batch=71.30828034
# x_batch=37.0 y_batch=34.59311043
# x_batch=23.0 y_batch=19.02332876
# x_batch=11.0 y_batch=10.76669688
# x_batch=88.0 y_batch=90.5799868
# x_batch=47.0 y_batch=48.71787679
# x_batch=79.0 y_batch=78.74139764
# x_batch=91.0 y_batch=85.23492274
# x_batch=71.0 y_batch=71.65789964
# x_batch=10.0 y_batch=8.938990554
# x_batch=39.0 y_batch=39.89606046
# x_batch=92.0 y_batch=91.85091116
# x_batch=99.0 y_batch=99.11200375
# x_batch=28.0 y_batch=26.22196486
# x_batch=32.0 y_batch=33.21584226
# x_batch=32.0 y_batch=35.72392691
# x_batch=75.0 y_batch=76.88604495
# x_batch=99.0 y_batch=99.30874567
# x_batch=27.0 y_batch=25.77161074
# x_batch=64.0 y_batch=67.85169407
# x_batch=98.0 y_batch=98.50371084
# x_batch=38.0 y_batch=31.11331895
# x_batch=46.0 y_batch=45.51171028
# x_batch=13.0 y_batch=12.65537808
# x_batch=96.0 y_batch=95.56065366
# x_batch=9.0 y_batch=9.526431641
# x_batch=34.0 y_batch=36.10893209
# x_batch=49.0 y_batch=46.43628318
# x_batch=1.0 y_batch=-3.83998112
# x_batch=50.0 y_batch=48.97302037
# x_batch=94.0 y_batch=93.25305499
# x_batch=27.0 y_batch=23.47650968
# x_batch=20.0 y_batch=17.13551132
# x_batch=12.0 y_batch=14.55896144
# x_batch=45.0 y_batch=41.53992729
# x_batch=91.0 y_batch=91.64730552
# x_batch=61.0 y_batch=66.16652565
# x_batch=10.0 y_batch=9.230857489
# x_batch=47.0 y_batch=47.41377893
# x_batch=33.0 y_batch=34.76441561
# x_batch=84.0 y_batch=86.10796637
# x_batch=24.0 y_batch=21.81267954
# x_batch=48.0 y_batch=48.89963951
# x_batch=48.0 y_batch=46.78108638
# x_batch=9.0 y_batch=12.91328547
# x_batch=93.0 y_batch=94.55203143
# x_batch=99.0 y_batch=94.97068753
# x_batch=8.0 y_batch=2.379172481
# x_batch=20.0 y_batch=21.47982988
# x_batch=38.0 y_batch=35.79795462
# x_batch=78.0 y_batch=82.0763803
# x_batch=81.0 y_batch=78.87097714
# x_batch=42.0 y_batch=47.2492425
# x_batch=95.0 y_batch=96.18852325
# x_batch=78.0 y_batch=78.38491927
# x_batch=44.0 y_batch=42.94274064
# x_batch=68.0 y_batch=64.43231595
# x_batch=87.0 y_batch=84.21191485
# x_batch=58.0 y_batch=57.3069783
# x_batch=52.0 y_batch=52.52101436
# x_batch=26.0 y_batch=25.7440243
# x_batch=75.0 y_batch=75.42283401
# x_batch=48.0 y_batch=53.62523007
# x_batch=71.0 y_batch=75.14466308
# x_batch=77.0 y_batch=74.12151511
# x_batch=34.0 y_batch=36.24807243
# x_batch=24.0 y_batch=20.21665898
# x_batch=70.0 y_batch=66.94758118
# x_batch=29.0 y_batch=34.07278254
# x_batch=76.0 y_batch=73.13850045
# x_batch=98.0 y_batch=92.85929155
# x_batch=28.0 y_batch=28.36793808
# x_batch=87.0 y_batch=85.59308727
# x_batch=9.0 y_batch=10.68453755
# x_batch=87.0 y_batch=86.10708624
# x_batch=33.0 y_batch=33.22031418
# x_batch=64.0 y_batch=66.09563422
# x_batch=17.0 y_batch=19.30486546
# x_batch=49.0 y_batch=48.84542083
# x_batch=95.0 y_batch=93.73176312
# x_batch=75.0 y_batch=75.45758614
# x_batch=89.0 y_batch=91.24239226
# x_batch=81.0 y_batch=87.15690853
# x_batch=25.0 y_batch=25.53752833
# x_batch=47.0 y_batch=46.06629478
# x_batch=50.0 y_batch=49.65277661
# x_batch=5.0 y_batch=7.382244165
# x_batch=68.0 y_batch=71.11189935
# x_batch=84.0 y_batch=83.50570521
# x_batch=8.0 y_batch=8.791139893
# x_batch=41.0 y_batch=33.30638903
# x_batch=26.0 y_batch=26.40362524
# x_batch=89.0 y_batch=91.72960726
# x_batch=78.0 y_batch=82.53030719
# x_batch=34.0 y_batch=36.67762733
# x_batch=92.0 y_batch=86.98450355
# x_batch=27.0 y_batch=32.34784175
# x_batch=12.0 y_batch=16.78353974
# x_batch=2.0 y_batch=1.576584383
# x_batch=22.0 y_batch=17.4618141
# x_batch=0.0 y_batch=2.116113029
# x_batch=26.0 y_batch=24.34804332
# x_batch=50.0 y_batch=48.29491198
# x_batch=84.0 y_batch=85.52145453
# x_batch=70.0 y_batch=73.71434779
# x_batch=66.0 y_batch=63.15189497
# x_batch=42.0 y_batch=38.46213684
# x_batch=19.0 y_batch=19.47100788
# x_batch=94.0 y_batch=94.07428225
# x_batch=71.0 y_batch=67.92051286
# x_batch=19.0 y_batch=22.58096241
# x_batch=16.0 y_batch=16.01629889
# x_batch=49.0 y_batch=48.43307886
# x_batch=29.0 y_batch=29.6673599
# x_batch=29.0 y_batch=26.65566328
# x_batch=86.0 y_batch=86.28206739
# x_batch=50.0 y_batch=50.82304924
# x_batch=86.0 y_batch=88.57251713
# x_batch=30.0 y_batch=32.59980745
# x_batch=23.0 y_batch=21.02469368
# x_batch=20.0 y_batch=20.72894979
# x_batch=16.0 y_batch=20.38051187
# x_batch=57.0 y_batch=57.25180153
# x_batch=8.0 y_batch=6.967537054
# x_batch=8.0 y_batch=10.240085
# x_batch=62.0 y_batch=64.94841088
# x_batch=55.0 y_batch=55.35893915
# x_batch=30.0 y_batch=31.24365589
# x_batch=86.0 y_batch=90.72048818
# x_batch=62.0 y_batch=58.750127
# x_batch=51.0 y_batch=55.85003198
# x_batch=61.0 y_batch=60.19925869
# x_batch=86.0 y_batch=85.03295412
# x_batch=61.0 y_batch=60.38823085
# x_batch=21.0 y_batch=18.44679787
# x_batch=81.0 y_batch=82.18839247
# x_batch=97.0 y_batch=94.2963344
# x_batch=5.0 y_batch=7.682024586
# x_batch=61.0 y_batch=61.01858089
# x_batch=47.0 y_batch=53.60562216
# x_batch=98.0 y_batch=94.47728801
# x_batch=30.0 y_batch=27.9645947
# x_batch=63.0 y_batch=62.55662585
# x_batch=0.0 y_batch=1.406254414
# x_batch=100.0 y_batch=101.7003412
# x_batch=18.0 y_batch=13.84973988
# x_batch=30.0 y_batch=28.99769315
# x_batch=98.0 y_batch=99.04315693
# x_batch=16.0 y_batch=15.56135514
# x_batch=22.0 y_batch=24.63528393
# x_batch=55.0 y_batch=53.98393374
# x_batch=43.0 y_batch=42.91449728
# x_batch=75.0 y_batch=74.29662112
# x_batch=91.0 y_batch=91.17012883
# x_batch=46.0 y_batch=49.42440876
# x_batch=85.0 y_batch=82.47683519
# x_batch=55.0 y_batch=56.15303953
# x_batch=36.0 y_batch=37.17063131
# x_batch=49.0 y_batch=46.36928662
# x_batch=94.0 y_batch=97.02383456
# x_batch=43.0 y_batch=40.83182104
# x_batch=22.0 y_batch=24.08498313
# x_batch=37.0 y_batch=41.14386358
# x_batch=24.0 y_batch=21.97388066
# x_batch=95.0 y_batch=100.740897
# x_batch=61.0 y_batch=61.19971596
# x_batch=75.0 y_batch=74.39517002
# x_batch=68.0 y_batch=69.04377173
# x_batch=58.0 y_batch=56.68718792
# x_batch=5.0 y_batch=5.860391715
# x_batch=53.0 y_batch=55.72021356
# x_batch=80.0 y_batch=79.22021816
# x_batch=83.0 y_batch=86.30177517
# x_batch=25.0 y_batch=25.26971886
# x_batch=34.0 y_batch=36.33294447
# x_batch=26.0 y_batch=27.65574228
# x_batch=90.0 y_batch=94.79690531
# x_batch=60.0 y_batch=58.67366671
# x_batch=49.0 y_batch=56.15934471
# x_batch=19.0 y_batch=18.40919388
# x_batch=92.0 y_batch=86.26936988
# x_batch=29.0 y_batch=26.59436195
# x_batch=8.0 y_batch=8.452520159
# x_batch=57.0 y_batch=56.18131518
# x_batch=29.0 y_batch=27.65452669
# x_batch=19.0 y_batch=20.87391785
# x_batch=81.0 y_batch=77.83354439
# x_batch=50.0 y_batch=50.01787825
# x_batch=15.0 y_batch=9.290856256
# x_batch=70.0 y_batch=75.0284725
# x_batch=39.0 y_batch=38.3037698
# x_batch=43.0 y_batch=44.70786405
# x_batch=21.0 y_batch=22.51016575
# x_batch=98.0 y_batch=102.4959452
# x_batch=86.0 y_batch=86.76845244
# x_batch=16.0 y_batch=13.89748578
# x_batch=25.0 y_batch=24.81824269
# x_batch=31.0 y_batch=33.94224862
# x_batch=93.0 y_batch=92.26970059
# x_batch=67.0 y_batch=68.73365081
# x_batch=49.0 y_batch=47.38516883
# x_batch=25.0 y_batch=32.37576914
# x_batch=88.0 y_batch=87.67388681
# x_batch=54.0 y_batch=54.57648371
# x_batch=21.0 y_batch=18.06450222
# x_batch=8.0 y_batch=7.896539841
# x_batch=32.0 y_batch=35.00341078
# x_batch=35.0 y_batch=36.72823317
# x_batch=67.0 y_batch=65.84975426
# x_batch=90.0 y_batch=89.59295492
# x_batch=59.0 y_batch=61.69026202
# x_batch=15.0 y_batch=11.60499315
# x_batch=67.0 y_batch=71.0826803
# x_batch=42.0 y_batch=43.71901164
# x_batch=44.0 y_batch=41.57421008
# x_batch=77.0 y_batch=74.25552425
# x_batch=68.0 y_batch=66.28310437
# x_batch=36.0 y_batch=36.62438077
# x_batch=11.0 y_batch=10.32374866
# x_batch=10.0 y_batch=7.156457657
# x_batch=65.0 y_batch=67.88603132
# x_batch=98.0 y_batch=101.1097591
# x_batch=98.0 y_batch=98.6132033
# x_batch=49.0 y_batch=50.19083844
# x_batch=31.0 y_batch=27.83896261
# x_batch=56.0 y_batch=55.9249564
# x_batch=70.0 y_batch=76.47340872
# x_batch=91.0 y_batch=92.05756378
# x_batch=25.0 y_batch=27.35245439
# x_batch=54.0 y_batch=55.32083476
# x_batch=39.0 y_batch=41.39990349
# x_batch=91.0 y_batch=93.59057024
# x_batch=3.0 y_batch=5.297054029
# x_batch=22.0 y_batch=21.01429422
# x_batch=2.0 y_batch=2.267059451
# x_batch=2.0 y_batch=-0.121860502
# x_batch=65.0 y_batch=66.49546208
# x_batch=71.0 y_batch=73.83637687
# x_batch=42.0 y_batch=42.10140878
# x_batch=76.0 y_batch=77.35135732
# x_batch=43.0 y_batch=41.02251779
# x_batch=8.0 y_batch=14.75305272
# x_batch=86.0 y_batch=83.28199022
# x_batch=87.0 y_batch=89.93374342
# x_batch=3.0 y_batch=2.286571686
# x_batch=58.0 y_batch=55.61421297
# x_batch=62.0 y_batch=62.15313408
# x_batch=89.0 y_batch=89.55803528
# x_batch=95.0 y_batch=94.00291863
# x_batch=28.0 y_batch=26.78023848
# x_batch=0.0 y_batch=-0.764537626
# x_batch=1.0 y_batch=0.282866003
# x_batch=49.0 y_batch=44.26800515
# x_batch=21.0 y_batch=19.85174138
# x_batch=46.0 y_batch=47.15960005
# x_batch=11.0 y_batch=8.359366572
# x_batch=89.0 y_batch=92.08157084
# x_batch=37.0 y_batch=41.88734051
# x_batch=29.0 y_batch=30.5413129
# x_batch=44.0 y_batch=46.87654473
# x_batch=96.0 y_batch=96.35659485
# x_batch=16.0 y_batch=17.9170699
# x_batch=74.0 y_batch=71.67949917
# x_batch=35.0 y_batch=32.64997554
# x_batch=42.0 y_batch=39.34482965
# x_batch=16.0 y_batch=17.03401999
# x_batch=56.0 y_batch=52.87524074
# x_batch=18.0 y_batch=15.85414849
# x_batch=100.0 y_batch=108.8716183
# x_batch=54.0 y_batch=49.30477253
# x_batch=92.0 y_batch=89.4749477
# x_batch=63.0 y_batch=63.67348242
# x_batch=81.0 y_batch=83.78410946
# x_batch=73.0 y_batch=73.51136922
# x_batch=48.0 y_batch=46.80297244
# x_batch=1.0 y_batch=5.809946802
# x_batch=85.0 y_batch=85.23027975
# x_batch=14.0 y_batch=10.58213964
# x_batch=25.0 y_batch=21.37698317
# x_batch=45.0 y_batch=46.0537745
# x_batch=98.0 y_batch=95.2389253
# x_batch=97.0 y_batch=94.15149206
# x_batch=58.0 y_batch=54.54868046
# x_batch=93.0 y_batch=87.36260449
# x_batch=88.0 y_batch=88.47741598
# x_batch=89.0 y_batch=84.48045678
# x_batch=47.0 y_batch=48.79647071
# x_batch=6.0 y_batch=10.76675683
# x_batch=34.0 y_batch=30.48882921
# x_batch=30.0 y_batch=29.76846185
# x_batch=16.0 y_batch=13.51574749
# x_batch=86.0 y_batch=86.12955884
# x_batch=40.0 y_batch=43.30022747
# x_batch=52.0 y_batch=51.92110232
# x_batch=15.0 y_batch=16.49185287
# x_batch=4.0 y_batch=7.998073432
# x_batch=95.0 y_batch=97.66689567
# x_batch=99.0 y_batch=89.80545367
# x_batch=35.0 y_batch=38.07166567
# x_batch=58.0 y_batch=60.27852322
# x_batch=10.0 y_batch=6.709195759
# x_batch=16.0 y_batch=18.35488924
# x_batch=53.0 y_batch=56.37058203
# x_batch=58.0 y_batch=62.80064204
# x_batch=42.0 y_batch=41.25155632
# x_batch=24.0 y_batch=19.42637541
# x_batch=84.0 y_batch=82.88935804
# x_batch=64.0 y_batch=63.61364981
# x_batch=12.0 y_batch=11.29627199
# x_batch=61.0 y_batch=60.02274882
# x_batch=75.0 y_batch=72.60339326
# x_batch=15.0 y_batch=11.87964573
# x_batch=100.0 y_batch=100.7012737
# x_batch=43.0 y_batch=45.12420809
# x_batch=13.0 y_batch=14.81106804
# x_batch=48.0 y_batch=48.09368034
# x_batch=45.0 y_batch=42.29145672
# x_batch=52.0 y_batch=52.73389794
# x_batch=34.0 y_batch=36.72396986
# x_batch=30.0 y_batch=28.64535198
# x_batch=65.0 y_batch=62.16675273
# x_batch=100.0 y_batch=95.58459518
# x_batch=67.0 y_batch=66.04325304
# x_batch=99.0 y_batch=99.9566225
# x_batch=45.0 y_batch=46.14941984
# x_batch=87.0 y_batch=89.13754963
# x_batch=73.0 y_batch=69.71787806
# x_batch=9.0 y_batch=12.31736648
# x_batch=81.0 y_batch=78.20296268
# x_batch=72.0 y_batch=71.30995371
# x_batch=81.0 y_batch=81.45544709
# x_batch=58.0 y_batch=58.59500642
# x_batch=93.0 y_batch=94.62509374
# x_batch=82.0 y_batch=88.60376995
# x_batch=66.0 y_batch=63.64868529
# x_batch=97.0 y_batch=94.9752655
# Epoch 0: nan
# x_batch=24.0 y_batch=21.54945196
# x_batch=50.0 y_batch=47.46446305
# x_batch=15.0 y_batch=17.21865634
# x_batch=38.0 y_batch=36.58639803
# x_batch=87.0 y_batch=87.28898389
# x_batch=36.0 y_batch=32.46387493
# x_batch=12.0 y_batch=10.78089683
# x_batch=81.0 y_batch=80.7633986
# x_batch=25.0 y_batch=24.61215147
# x_batch=5.0 y_batch=6.963319071
# x_batch=16.0 y_batch=11.23757338
# x_batch=16.0 y_batch=13.53290206
# x_batch=24.0 y_batch=24.60323899
# x_batch=39.0 y_batch=39.40049976
# x_batch=54.0 y_batch=48.43753838
# x_batch=60.0 y_batch=61.69900319
# x_batch=26.0 y_batch=26.92832418
# x_batch=73.0 y_batch=70.4052055
# x_batch=29.0 y_batch=29.34092408
# x_batch=31.0 y_batch=25.30895192
# x_batch=68.0 y_batch=69.02934339
# x_batch=87.0 y_batch=84.99484703
# x_batch=58.0 y_batch=57.04310305
# x_batch=54.0 y_batch=50.5921991
# x_batch=84.0 y_batch=83.02772202
# x_batch=58.0 y_batch=57.05752706
# x_batch=49.0 y_batch=47.95883341
# x_batch=20.0 y_batch=24.34226432
# x_batch=90.0 y_batch=94.68488281
# x_batch=48.0 y_batch=48.03970696
# x_batch=4.0 y_batch=7.08132338
# x_batch=25.0 y_batch=21.99239907
# x_batch=42.0 y_batch=42.33151664
# x_batch=0.0 y_batch=0.329089443
# x_batch=60.0 y_batch=61.92303698
# x_batch=93.0 y_batch=91.17716423
# x_batch=39.0 y_batch=39.45358014
# x_batch=7.0 y_batch=5.996069607
# x_batch=21.0 y_batch=22.59015942
# x_batch=68.0 y_batch=61.18044414
# x_batch=84.0 y_batch=85.02778957
# x_batch=0.0 y_batch=-1.28631089
# x_batch=58.0 y_batch=61.94273962
# x_batch=19.0 y_batch=21.96033347
# x_batch=36.0 y_batch=33.66194193
# x_batch=19.0 y_batch=17.60946242
# x_batch=59.0 y_batch=58.5630564
# x_batch=51.0 y_batch=52.82390762
# x_batch=19.0 y_batch=22.1363481
# x_batch=33.0 y_batch=35.07467353
# x_batch=85.0 y_batch=86.18822311
# x_batch=44.0 y_batch=42.63227697
# x_batch=5.0 y_batch=4.09817744
# x_batch=59.0 y_batch=61.2229864
# x_batch=14.0 y_batch=17.70677576
# x_batch=9.0 y_batch=11.85312574
# x_batch=75.0 y_batch=80.23051695
# x_batch=69.0 y_batch=62.64931741
# x_batch=10.0 y_batch=9.616859804
# x_batch=17.0 y_batch=20.02797699
# x_batch=58.0 y_batch=61.7510743
# x_batch=74.0 y_batch=71.61010303
# x_batch=21.0 y_batch=23.77154623
# x_batch=51.0 y_batch=51.90142035
# x_batch=19.0 y_batch=22.66073682
# x_batch=50.0 y_batch=50.02897927
# x_batch=24.0 y_batch=26.68794368
# x_batch=0.0 y_batch=0.376911899
# x_batch=12.0 y_batch=6.806419002
# x_batch=75.0 y_batch=77.33986001
# x_batch=21.0 y_batch=28.90260209
# x_batch=64.0 y_batch=66.7346608
# x_batch=5.0 y_batch=0.707510638
# x_batch=58.0 y_batch=57.07748383
# x_batch=32.0 y_batch=28.41453196
# x_batch=41.0 y_batch=44.46272123
# x_batch=7.0 y_batch=7.459605998
# x_batch=4.0 y_batch=2.316708112
# x_batch=5.0 y_batch=4.928546187
# x_batch=49.0 y_batch=52.50336074
# x_batch=90.0 y_batch=91.19109623
# x_batch=3.0 y_batch=8.489164326
# x_batch=11.0 y_batch=6.963371967
# x_batch=32.0 y_batch=31.97989959
# x_batch=83.0 y_batch=81.4281205
# x_batch=25.0 y_batch=22.62365422
# x_batch=83.0 y_batch=78.52505087
# x_batch=26.0 y_batch=25.80714057
# x_batch=76.0 y_batch=73.51081775
# x_batch=95.0 y_batch=91.775467
# x_batch=53.0 y_batch=49.21863516
# x_batch=77.0 y_batch=80.50445387
# x_batch=42.0 y_batch=50.05636123
# x_batch=25.0 y_batch=25.46292549
# x_batch=54.0 y_batch=55.32164264
# x_batch=55.0 y_batch=59.1244888
# x_batch=0.0 y_batch=1.100686692
# x_batch=73.0 y_batch=71.98020786
# x_batch=35.0 y_batch=30.13666408
# x_batch=86.0 y_batch=83.88427405
# x_batch=90.0 y_batch=89.91004752
# x_batch=13.0 y_batch=8.335654576
# x_batch=46.0 y_batch=47.88388961
# x_batch=46.0 y_batch=45.00397413
# x_batch=32.0 y_batch=31.15664574
# x_batch=8.0 y_batch=9.190375682
# x_batch=71.0 y_batch=74.83135003
# x_batch=28.0 y_batch=30.23177607
# x_batch=24.0 y_batch=24.21914027
# x_batch=56.0 y_batch=57.87219151
# x_batch=49.0 y_batch=50.61728392
# x_batch=79.0 y_batch=78.67470043
# x_batch=90.0 y_batch=86.236707
# x_batch=89.0 y_batch=89.10409255
# x_batch=41.0 y_batch=43.26595082
# x_batch=27.0 y_batch=26.68273277
# x_batch=58.0 y_batch=59.46383041
# x_batch=26.0 y_batch=28.90055826
# x_batch=31.0 y_batch=31.300416
# x_batch=70.0 y_batch=71.1433266
# x_batch=71.0 y_batch=68.4739206
# x_batch=39.0 y_batch=39.98238856
# x_batch=7.0 y_batch=4.075776144
# x_batch=48.0 y_batch=47.85817542
# x_batch=56.0 y_batch=51.20390217
# x_batch=45.0 y_batch=43.9367213
# x_batch=41.0 y_batch=38.13626679
# x_batch=3.0 y_batch=3.574661632
# x_batch=37.0 y_batch=36.4139958
# x_batch=24.0 y_batch=22.21908523
# x_batch=68.0 y_batch=63.5312572
# x_batch=47.0 y_batch=49.86702787
# x_batch=27.0 y_batch=21.53140009
# x_batch=68.0 y_batch=64.05710234
# x_batch=74.0 y_batch=70.77549842
# x_batch=95.0 y_batch=92.15749762
# x_batch=79.0 y_batch=81.22259156
# x_batch=21.0 y_batch=25.10114067
# x_batch=95.0 y_batch=94.08853397
# x_batch=54.0 y_batch=53.25166165
# x_batch=56.0 y_batch=59.16236621
# x_batch=80.0 y_batch=75.24148428
# x_batch=26.0 y_batch=28.22325833
# x_batch=25.0 y_batch=25.33323728
# x_batch=8.0 y_batch=6.364615703
# x_batch=95.0 y_batch=95.4609216
# x_batch=94.0 y_batch=88.64183756
# x_batch=54.0 y_batch=58.70318693
# x_batch=7.0 y_batch=6.815491279
# x_batch=99.0 y_batch=99.40394676
# x_batch=36.0 y_batch=32.77049249
# x_batch=48.0 y_batch=47.0586788
# x_batch=65.0 y_batch=60.53321778
# x_batch=42.0 y_batch=40.30929858
# x_batch=93.0 y_batch=89.42222685
# x_batch=86.0 y_batch=86.82132066
# x_batch=26.0 y_batch=26.11697543
# x_batch=51.0 y_batch=53.26657596
# x_batch=100.0 y_batch=96.62327888
# x_batch=94.0 y_batch=95.78441027
# x_batch=6.0 y_batch=6.047286687
# x_batch=24.0 y_batch=24.47387908
# x_batch=75.0 y_batch=75.96844763
# x_batch=7.0 y_batch=3.829381009
# x_batch=53.0 y_batch=52.51703683
# x_batch=73.0 y_batch=72.80457527
# x_batch=16.0 y_batch=14.10999096
# x_batch=80.0 y_batch=80.86087062
# x_batch=77.0 y_batch=77.01988215
# x_batch=89.0 y_batch=86.26972444
# x_batch=80.0 y_batch=77.13735466
# x_batch=55.0 y_batch=51.47649476
# x_batch=19.0 y_batch=17.34557531
# x_batch=56.0 y_batch=57.72853572
# x_batch=47.0 y_batch=44.15029394
# x_batch=56.0 y_batch=59.24362743
# x_batch=2.0 y_batch=-1.053275611
# x_batch=82.0 y_batch=86.79002254
# x_batch=57.0 y_batch=60.14031858
# x_batch=44.0 y_batch=44.04222058
# x_batch=26.0 y_batch=24.5227488
# x_batch=52.0 y_batch=52.95305521
# x_batch=41.0 y_batch=43.16133498
# x_batch=44.0 y_batch=45.67562576
# x_batch=3.0 y_batch=-2.830749501
# x_batch=31.0 y_batch=29.19693178
# x_batch=97.0 y_batch=96.49812401
# x_batch=21.0 y_batch=22.5453232
# x_batch=17.0 y_batch=20.10741433
# x_batch=7.0 y_batch=4.035430253
# x_batch=61.0 y_batch=61.14568518
# x_batch=10.0 y_batch=13.97163653
# x_batch=52.0 y_batch=55.34529893
# x_batch=10.0 y_batch=12.18441166
# x_batch=65.0 y_batch=64.00077658
# x_batch=71.0 y_batch=70.3188322
# x_batch=4.0 y_batch=-0.936895047
# x_batch=24.0 y_batch=18.91422276
# x_batch=26.0 y_batch=23.87590331
# x_batch=51.0 y_batch=47.5775361
# x_batch=42.0 y_batch=43.2736092
# x_batch=62.0 y_batch=66.48278755
# x_batch=74.0 y_batch=75.72605529
# x_batch=77.0 y_batch=80.59643338
# x_batch=3.0 y_batch=-2.235879852
# x_batch=50.0 y_batch=47.04654956
# x_batch=24.0 y_batch=21.59635575
# x_batch=37.0 y_batch=32.87558963
# x_batch=58.0 y_batch=57.95782956
# x_batch=52.0 y_batch=52.24760027
# x_batch=27.0 y_batch=24.58286902
# x_batch=14.0 y_batch=12.12573805
# x_batch=100.0 y_batch=100.0158026
# x_batch=72.0 y_batch=74.04682658
# x_batch=5.0 y_batch=1.611947467
# x_batch=71.0 y_batch=70.36836307
# x_batch=54.0 y_batch=52.26831735
# x_batch=84.0 y_batch=83.1286166
# x_batch=42.0 y_batch=43.64765048
# x_batch=54.0 y_batch=49.44785426
# x_batch=74.0 y_batch=72.6356699
# x_batch=54.0 y_batch=52.78130641
# x_batch=53.0 y_batch=57.11195136
# x_batch=78.0 y_batch=79.1050629
# x_batch=97.0 y_batch=101.6228548
# x_batch=49.0 y_batch=53.5825402
# x_batch=71.0 y_batch=68.92139297
# x_batch=48.0 y_batch=46.9666961
# x_batch=51.0 y_batch=51.02642868
# x_batch=89.0 y_batch=85.52073551
# x_batch=99.0 y_batch=99.51685756
# x_batch=93.0 y_batch=94.63911256
# x_batch=49.0 y_batch=46.78357742
# x_batch=18.0 y_batch=21.21321959
# x_batch=65.0 y_batch=58.37266004
# x_batch=83.0 y_batch=87.22059677
# x_batch=100.0 y_batch=102.4967859
# x_batch=41.0 y_batch=43.88314335
# x_batch=52.0 y_batch=53.06655757
# x_batch=29.0 y_batch=26.33464785
# x_batch=97.0 y_batch=98.52008934
# x_batch=7.0 y_batch=9.400497579
# x_batch=51.0 y_batch=52.94026699
# x_batch=58.0 y_batch=53.83020877
# x_batch=50.0 y_batch=45.94511142
# x_batch=67.0 y_batch=65.0132736
# x_batch=89.0 y_batch=86.5069584
# x_batch=76.0 y_batch=75.63280796
# x_batch=35.0 y_batch=36.78035027
# x_batch=99.0 y_batch=100.5328916
# x_batch=31.0 y_batch=29.04466136
# x_batch=52.0 y_batch=51.70352433
# x_batch=11.0 y_batch=9.199954718
# x_batch=66.0 y_batch=71.70015848
# x_batch=50.0 y_batch=49.82634062
# x_batch=39.0 y_batch=37.49971096
# x_batch=60.0 y_batch=53.65084683
# x_batch=35.0 y_batch=33.92561965
# x_batch=53.0 y_batch=49.92639685
# x_batch=14.0 y_batch=8.148154262
# x_batch=49.0 y_batch=49.72359037
# x_batch=16.0 y_batch=16.16712757
# x_batch=76.0 y_batch=75.30033002
# x_batch=13.0 y_batch=9.577368568
# x_batch=51.0 y_batch=48.38088357
# x_batch=70.0 y_batch=72.95331671
# x_batch=98.0 y_batch=92.59573853
# x_batch=86.0 y_batch=88.85523586
# x_batch=100.0 y_batch=99.00361771
# x_batch=46.0 y_batch=45.09439571
# x_batch=51.0 y_batch=46.94362684
# x_batch=50.0 y_batch=48.33449605
# x_batch=91.0 y_batch=94.92329574
# x_batch=48.0 y_batch=47.78165248
# x_batch=81.0 y_batch=81.28960746
# x_batch=38.0 y_batch=37.83155021
# x_batch=40.0 y_batch=39.69185252
# x_batch=79.0 y_batch=76.92664854
# x_batch=96.0 y_batch=88.02990531
# x_batch=60.0 y_batch=56.99178872
# x_batch=70.0 y_batch=72.58929383
# x_batch=44.0 y_batch=44.98103442
# x_batch=11.0 y_batch=11.99017641
# x_batch=6.0 y_batch=1.919513328
# x_batch=5.0 y_batch=1.628826073
# x_batch=72.0 y_batch=66.27746655
# x_batch=55.0 y_batch=57.53887255
# x_batch=95.0 y_batch=94.70291077
# x_batch=41.0 y_batch=41.21469904
# x_batch=25.0 y_batch=25.04169243
# x_batch=1.0 y_batch=3.778209914
# x_batch=55.0 y_batch=50.50711779
# x_batch=4.0 y_batch=9.682408486
# x_batch=48.0 y_batch=48.88147608
# x_batch=55.0 y_batch=54.40348599
# x_batch=75.0 y_batch=71.70233156
# x_batch=68.0 y_batch=69.35848388
# x_batch=100.0 y_batch=99.98491591
# x_batch=25.0 y_batch=26.03323718
# x_batch=75.0 y_batch=75.48910307
# x_batch=34.0 y_batch=36.59623056
# x_batch=38.0 y_batch=40.95102191
# x_batch=92.0 y_batch=86.78316267
# x_batch=21.0 y_batch=15.50701184
# x_batch=88.0 y_batch=85.86077871
# x_batch=75.0 y_batch=79.20610113
# x_batch=76.0 y_batch=80.80643766
# x_batch=44.0 y_batch=48.59717283
# x_batch=10.0 y_batch=13.93415049
# x_batch=21.0 y_batch=27.3051179
# x_batch=16.0 y_batch=14.00226297
# x_batch=32.0 y_batch=33.67416
# x_batch=13.0 y_batch=13.11612884
# x_batch=26.0 y_batch=24.76649193
# x_batch=70.0 y_batch=73.68477876
# x_batch=77.0 y_batch=77.53149541
# x_batch=77.0 y_batch=76.24503196
# x_batch=88.0 y_batch=88.0578931
# x_batch=35.0 y_batch=35.02445799
# x_batch=24.0 y_batch=21.65857739
# x_batch=17.0 y_batch=17.33681562
# x_batch=91.0 y_batch=94.36778957
# x_batch=32.0 y_batch=33.43396307
# x_batch=36.0 y_batch=32.52179399
# x_batch=89.0 y_batch=90.57741298
# x_batch=69.0 y_batch=71.25634126
# x_batch=30.0 y_batch=31.23212856
# x_batch=6.0 y_batch=5.398840061
# x_batch=22.0 y_batch=18.56241391
# x_batch=67.0 y_batch=71.97121038
# x_batch=9.0 y_batch=5.225759566
# x_batch=74.0 y_batch=73.5964342
# x_batch=50.0 y_batch=49.76948983
# x_batch=85.0 y_batch=82.69087513
# x_batch=3.0 y_batch=1.652309089
# x_batch=0.0 y_batch=-3.836652144
# x_batch=59.0 y_batch=62.03811556
# x_batch=62.0 y_batch=61.26514581
# x_batch=17.0 y_batch=13.24991628
# x_batch=90.0 y_batch=88.61672694
# x_batch=23.0 y_batch=21.13655528
# x_batch=19.0 y_batch=23.85017475
# x_batch=93.0 y_batch=92.01203405
# x_batch=14.0 y_batch=10.26712261
# x_batch=58.0 y_batch=54.14681616
# x_batch=87.0 y_batch=87.00645713
# x_batch=37.0 y_batch=37.69447352
# x_batch=20.0 y_batch=19.62278654
# x_batch=35.0 y_batch=34.78561007
# x_batch=63.0 y_batch=62.03190983
# x_batch=56.0 y_batch=52.67003801
# x_batch=62.0 y_batch=58.09031476
# x_batch=98.0 y_batch=97.19448821
# x_batch=90.0 y_batch=90.50155298
# x_batch=51.0 y_batch=50.5123462
# x_batch=93.0 y_batch=94.45211871
# x_batch=22.0 y_batch=21.10794636
# x_batch=38.0 y_batch=37.36298431
# x_batch=13.0 y_batch=10.28574844
# x_batch=98.0 y_batch=96.04932416
# x_batch=99.0 y_batch=100.0953697
# x_batch=31.0 y_batch=30.6063167
# x_batch=94.0 y_batch=96.19000542
# x_batch=73.0 y_batch=71.30828034
# x_batch=37.0 y_batch=34.59311043
# x_batch=23.0 y_batch=19.02332876
# x_batch=11.0 y_batch=10.76669688
# x_batch=88.0 y_batch=90.5799868
# x_batch=47.0 y_batch=48.71787679
# x_batch=79.0 y_batch=78.74139764
# x_batch=91.0 y_batch=85.23492274
# x_batch=71.0 y_batch=71.65789964
# x_batch=10.0 y_batch=8.938990554
# x_batch=39.0 y_batch=39.89606046
# x_batch=92.0 y_batch=91.85091116
# x_batch=99.0 y_batch=99.11200375
# x_batch=28.0 y_batch=26.22196486
# x_batch=32.0 y_batch=33.21584226
# x_batch=32.0 y_batch=35.72392691
# x_batch=75.0 y_batch=76.88604495
# x_batch=99.0 y_batch=99.30874567
# x_batch=27.0 y_batch=25.77161074
# x_batch=64.0 y_batch=67.85169407
# x_batch=98.0 y_batch=98.50371084
# x_batch=38.0 y_batch=31.11331895
# x_batch=46.0 y_batch=45.51171028
# x_batch=13.0 y_batch=12.65537808
# x_batch=96.0 y_batch=95.56065366
# x_batch=9.0 y_batch=9.526431641
# x_batch=34.0 y_batch=36.10893209
# x_batch=49.0 y_batch=46.43628318
# x_batch=1.0 y_batch=-3.83998112
# x_batch=50.0 y_batch=48.97302037
# x_batch=94.0 y_batch=93.25305499
# x_batch=27.0 y_batch=23.47650968
# x_batch=20.0 y_batch=17.13551132
# x_batch=12.0 y_batch=14.55896144
# x_batch=45.0 y_batch=41.53992729
# x_batch=91.0 y_batch=91.64730552
# x_batch=61.0 y_batch=66.16652565
# x_batch=10.0 y_batch=9.230857489
# x_batch=47.0 y_batch=47.41377893
# x_batch=33.0 y_batch=34.76441561
# x_batch=84.0 y_batch=86.10796637
# x_batch=24.0 y_batch=21.81267954
# x_batch=48.0 y_batch=48.89963951
# x_batch=48.0 y_batch=46.78108638
# x_batch=9.0 y_batch=12.91328547
# x_batch=93.0 y_batch=94.55203143
# x_batch=99.0 y_batch=94.97068753
# x_batch=8.0 y_batch=2.379172481
# x_batch=20.0 y_batch=21.47982988
# x_batch=38.0 y_batch=35.79795462
# x_batch=78.0 y_batch=82.0763803
# x_batch=81.0 y_batch=78.87097714
# x_batch=42.0 y_batch=47.2492425
# x_batch=95.0 y_batch=96.18852325
# x_batch=78.0 y_batch=78.38491927
# x_batch=44.0 y_batch=42.94274064
# x_batch=68.0 y_batch=64.43231595
# x_batch=87.0 y_batch=84.21191485
# x_batch=58.0 y_batch=57.3069783
# x_batch=52.0 y_batch=52.52101436
# x_batch=26.0 y_batch=25.7440243
# x_batch=75.0 y_batch=75.42283401
# x_batch=48.0 y_batch=53.62523007
# x_batch=71.0 y_batch=75.14466308
# x_batch=77.0 y_batch=74.12151511
# x_batch=34.0 y_batch=36.24807243
# x_batch=24.0 y_batch=20.21665898
# x_batch=70.0 y_batch=66.94758118
# x_batch=29.0 y_batch=34.07278254
# x_batch=76.0 y_batch=73.13850045
# x_batch=98.0 y_batch=92.85929155
# x_batch=28.0 y_batch=28.36793808
# x_batch=87.0 y_batch=85.59308727
# x_batch=9.0 y_batch=10.68453755
# x_batch=87.0 y_batch=86.10708624
# x_batch=33.0 y_batch=33.22031418
# x_batch=64.0 y_batch=66.09563422
# x_batch=17.0 y_batch=19.30486546
# x_batch=49.0 y_batch=48.84542083
# x_batch=95.0 y_batch=93.73176312
# x_batch=75.0 y_batch=75.45758614
# x_batch=89.0 y_batch=91.24239226
# x_batch=81.0 y_batch=87.15690853
# x_batch=25.0 y_batch=25.53752833
# x_batch=47.0 y_batch=46.06629478
# x_batch=50.0 y_batch=49.65277661
# x_batch=5.0 y_batch=7.382244165
# x_batch=68.0 y_batch=71.11189935
# x_batch=84.0 y_batch=83.50570521
# x_batch=8.0 y_batch=8.791139893
# x_batch=41.0 y_batch=33.30638903
# x_batch=26.0 y_batch=26.40362524
# x_batch=89.0 y_batch=91.72960726
# x_batch=78.0 y_batch=82.53030719
# x_batch=34.0 y_batch=36.67762733
# x_batch=92.0 y_batch=86.98450355
# x_batch=27.0 y_batch=32.34784175
# x_batch=12.0 y_batch=16.78353974
# x_batch=2.0 y_batch=1.576584383
# x_batch=22.0 y_batch=17.4618141
# x_batch=0.0 y_batch=2.116113029
# x_batch=26.0 y_batch=24.34804332
# x_batch=50.0 y_batch=48.29491198
# x_batch=84.0 y_batch=85.52145453
# x_batch=70.0 y_batch=73.71434779
# x_batch=66.0 y_batch=63.15189497
# x_batch=42.0 y_batch=38.46213684
# x_batch=19.0 y_batch=19.47100788
# x_batch=94.0 y_batch=94.07428225
# x_batch=71.0 y_batch=67.92051286
# x_batch=19.0 y_batch=22.58096241
# x_batch=16.0 y_batch=16.01629889
# x_batch=49.0 y_batch=48.43307886
# x_batch=29.0 y_batch=29.6673599
# x_batch=29.0 y_batch=26.65566328
# x_batch=86.0 y_batch=86.28206739
# x_batch=50.0 y_batch=50.82304924
# x_batch=86.0 y_batch=88.57251713
# x_batch=30.0 y_batch=32.59980745
# x_batch=23.0 y_batch=21.02469368
# x_batch=20.0 y_batch=20.72894979
# x_batch=16.0 y_batch=20.38051187
# x_batch=57.0 y_batch=57.25180153
# x_batch=8.0 y_batch=6.967537054
# x_batch=8.0 y_batch=10.240085
# x_batch=62.0 y_batch=64.94841088
# x_batch=55.0 y_batch=55.35893915
# x_batch=30.0 y_batch=31.24365589
# x_batch=86.0 y_batch=90.72048818
# x_batch=62.0 y_batch=58.750127
# x_batch=51.0 y_batch=55.85003198
# x_batch=61.0 y_batch=60.19925869
# x_batch=86.0 y_batch=85.03295412
# x_batch=61.0 y_batch=60.38823085
# x_batch=21.0 y_batch=18.44679787
# x_batch=81.0 y_batch=82.18839247
# x_batch=97.0 y_batch=94.2963344
# x_batch=5.0 y_batch=7.682024586
# x_batch=61.0 y_batch=61.01858089
# x_batch=47.0 y_batch=53.60562216
# x_batch=98.0 y_batch=94.47728801
# x_batch=30.0 y_batch=27.9645947
# x_batch=63.0 y_batch=62.55662585
# x_batch=0.0 y_batch=1.406254414
# x_batch=100.0 y_batch=101.7003412
# x_batch=18.0 y_batch=13.84973988
# x_batch=30.0 y_batch=28.99769315
# x_batch=98.0 y_batch=99.04315693
# x_batch=16.0 y_batch=15.56135514
# x_batch=22.0 y_batch=24.63528393
# x_batch=55.0 y_batch=53.98393374
# x_batch=43.0 y_batch=42.91449728
# x_batch=75.0 y_batch=74.29662112
# x_batch=91.0 y_batch=91.17012883
# x_batch=46.0 y_batch=49.42440876
# x_batch=85.0 y_batch=82.47683519
# x_batch=55.0 y_batch=56.15303953
# x_batch=36.0 y_batch=37.17063131
# x_batch=49.0 y_batch=46.36928662
# x_batch=94.0 y_batch=97.02383456
# x_batch=43.0 y_batch=40.83182104
# x_batch=22.0 y_batch=24.08498313
# x_batch=37.0 y_batch=41.14386358
# x_batch=24.0 y_batch=21.97388066
# x_batch=95.0 y_batch=100.740897
# x_batch=61.0 y_batch=61.19971596
# x_batch=75.0 y_batch=74.39517002
# x_batch=68.0 y_batch=69.04377173
# x_batch=58.0 y_batch=56.68718792
# x_batch=5.0 y_batch=5.860391715
# x_batch=53.0 y_batch=55.72021356
# x_batch=80.0 y_batch=79.22021816
# x_batch=83.0 y_batch=86.30177517
# x_batch=25.0 y_batch=25.26971886
# x_batch=34.0 y_batch=36.33294447
# x_batch=26.0 y_batch=27.65574228
# x_batch=90.0 y_batch=94.79690531
# x_batch=60.0 y_batch=58.67366671
# x_batch=49.0 y_batch=56.15934471
# x_batch=19.0 y_batch=18.40919388
# x_batch=92.0 y_batch=86.26936988
# x_batch=29.0 y_batch=26.59436195
# x_batch=8.0 y_batch=8.452520159
# x_batch=57.0 y_batch=56.18131518
# x_batch=29.0 y_batch=27.65452669
# x_batch=19.0 y_batch=20.87391785
# x_batch=81.0 y_batch=77.83354439
# x_batch=50.0 y_batch=50.01787825
# x_batch=15.0 y_batch=9.290856256
# x_batch=70.0 y_batch=75.0284725
# x_batch=39.0 y_batch=38.3037698
# x_batch=43.0 y_batch=44.70786405
# x_batch=21.0 y_batch=22.51016575
# x_batch=98.0 y_batch=102.4959452
# x_batch=86.0 y_batch=86.76845244
# x_batch=16.0 y_batch=13.89748578
# x_batch=25.0 y_batch=24.81824269
# x_batch=31.0 y_batch=33.94224862
# x_batch=93.0 y_batch=92.26970059
# x_batch=67.0 y_batch=68.73365081
# x_batch=49.0 y_batch=47.38516883
# x_batch=25.0 y_batch=32.37576914
# x_batch=88.0 y_batch=87.67388681
# x_batch=54.0 y_batch=54.57648371
# x_batch=21.0 y_batch=18.06450222
# x_batch=8.0 y_batch=7.896539841
# x_batch=32.0 y_batch=35.00341078
# x_batch=35.0 y_batch=36.72823317
# x_batch=67.0 y_batch=65.84975426
# x_batch=90.0 y_batch=89.59295492
# x_batch=59.0 y_batch=61.69026202
# x_batch=15.0 y_batch=11.60499315
# x_batch=67.0 y_batch=71.0826803
# x_batch=42.0 y_batch=43.71901164
# x_batch=44.0 y_batch=41.57421008
# x_batch=77.0 y_batch=74.25552425
# x_batch=68.0 y_batch=66.28310437
# x_batch=36.0 y_batch=36.62438077
# x_batch=11.0 y_batch=10.32374866
# x_batch=10.0 y_batch=7.156457657
# x_batch=65.0 y_batch=67.88603132
# x_batch=98.0 y_batch=101.1097591
# x_batch=98.0 y_batch=98.6132033
# x_batch=49.0 y_batch=50.19083844
# x_batch=31.0 y_batch=27.83896261
# x_batch=56.0 y_batch=55.9249564
# x_batch=70.0 y_batch=76.47340872
# x_batch=91.0 y_batch=92.05756378
# x_batch=25.0 y_batch=27.35245439
# x_batch=54.0 y_batch=55.32083476
# x_batch=39.0 y_batch=41.39990349
# x_batch=91.0 y_batch=93.59057024
# x_batch=3.0 y_batch=5.297054029
# x_batch=22.0 y_batch=21.01429422
# x_batch=2.0 y_batch=2.267059451
# x_batch=2.0 y_batch=-0.121860502
# x_batch=65.0 y_batch=66.49546208
# x_batch=71.0 y_batch=73.83637687
# x_batch=42.0 y_batch=42.10140878
# x_batch=76.0 y_batch=77.35135732
# x_batch=43.0 y_batch=41.02251779
# x_batch=8.0 y_batch=14.75305272
# x_batch=86.0 y_batch=83.28199022
# x_batch=87.0 y_batch=89.93374342
# x_batch=3.0 y_batch=2.286571686
# x_batch=58.0 y_batch=55.61421297
# x_batch=62.0 y_batch=62.15313408
# x_batch=89.0 y_batch=89.55803528
# x_batch=95.0 y_batch=94.00291863
# x_batch=28.0 y_batch=26.78023848
# x_batch=0.0 y_batch=-0.764537626
# x_batch=1.0 y_batch=0.282866003
# x_batch=49.0 y_batch=44.26800515
# x_batch=21.0 y_batch=19.85174138
# x_batch=46.0 y_batch=47.15960005
# x_batch=11.0 y_batch=8.359366572
# x_batch=89.0 y_batch=92.08157084
# x_batch=37.0 y_batch=41.88734051
# x_batch=29.0 y_batch=30.5413129
# x_batch=44.0 y_batch=46.87654473
# x_batch=96.0 y_batch=96.35659485
# x_batch=16.0 y_batch=17.9170699
# x_batch=74.0 y_batch=71.67949917
# x_batch=35.0 y_batch=32.64997554
# x_batch=42.0 y_batch=39.34482965
# x_batch=16.0 y_batch=17.03401999
# x_batch=56.0 y_batch=52.87524074
# x_batch=18.0 y_batch=15.85414849
# x_batch=100.0 y_batch=108.8716183
# x_batch=54.0 y_batch=49.30477253
# x_batch=92.0 y_batch=89.4749477
# x_batch=63.0 y_batch=63.67348242
# x_batch=81.0 y_batch=83.78410946
# x_batch=73.0 y_batch=73.51136922
# x_batch=48.0 y_batch=46.80297244
# x_batch=1.0 y_batch=5.809946802
# x_batch=85.0 y_batch=85.23027975
# x_batch=14.0 y_batch=10.58213964
# x_batch=25.0 y_batch=21.37698317
# x_batch=45.0 y_batch=46.0537745
# x_batch=98.0 y_batch=95.2389253
# x_batch=97.0 y_batch=94.15149206
# x_batch=58.0 y_batch=54.54868046
# x_batch=93.0 y_batch=87.36260449
# x_batch=88.0 y_batch=88.47741598
# x_batch=89.0 y_batch=84.48045678
# x_batch=47.0 y_batch=48.79647071
# x_batch=6.0 y_batch=10.76675683
# x_batch=34.0 y_batch=30.48882921
# x_batch=30.0 y_batch=29.76846185
# x_batch=16.0 y_batch=13.51574749
# x_batch=86.0 y_batch=86.12955884
# x_batch=40.0 y_batch=43.30022747
# x_batch=52.0 y_batch=51.92110232
# x_batch=15.0 y_batch=16.49185287
# x_batch=4.0 y_batch=7.998073432
# x_batch=95.0 y_batch=97.66689567
# x_batch=99.0 y_batch=89.80545367
# x_batch=35.0 y_batch=38.07166567
# x_batch=58.0 y_batch=60.27852322
# x_batch=10.0 y_batch=6.709195759
# x_batch=16.0 y_batch=18.35488924
# x_batch=53.0 y_batch=56.37058203
# x_batch=58.0 y_batch=62.80064204
# x_batch=42.0 y_batch=41.25155632
# x_batch=24.0 y_batch=19.42637541
# x_batch=84.0 y_batch=82.88935804
# x_batch=64.0 y_batch=63.61364981
# x_batch=12.0 y_batch=11.29627199
# x_batch=61.0 y_batch=60.02274882
# x_batch=75.0 y_batch=72.60339326
# x_batch=15.0 y_batch=11.87964573
# x_batch=100.0 y_batch=100.7012737
# x_batch=43.0 y_batch=45.12420809
# x_batch=13.0 y_batch=14.81106804
# x_batch=48.0 y_batch=48.09368034
# x_batch=45.0 y_batch=42.29145672
# x_batch=52.0 y_batch=52.73389794
# x_batch=34.0 y_batch=36.72396986
# x_batch=30.0 y_batch=28.64535198
# x_batch=65.0 y_batch=62.16675273
# x_batch=100.0 y_batch=95.58459518
# x_batch=67.0 y_batch=66.04325304
# x_batch=99.0 y_batch=99.9566225
# x_batch=45.0 y_batch=46.14941984
# x_batch=87.0 y_batch=89.13754963
# x_batch=73.0 y_batch=69.71787806
# x_batch=9.0 y_batch=12.31736648
# x_batch=81.0 y_batch=78.20296268
# x_batch=72.0 y_batch=71.30995371
# x_batch=81.0 y_batch=81.45544709
# x_batch=58.0 y_batch=58.59500642
# x_batch=93.0 y_batch=94.62509374
# x_batch=82.0 y_batch=88.60376995
# x_batch=66.0 y_batch=63.64868529
# x_batch=97.0 y_batch=94.9752655
# Epoch 1: nan
# x_batch=24.0 y_batch=21.54945196
# x_batch=50.0 y_batch=47.46446305
# x_batch=15.0 y_batch=17.21865634
# x_batch=38.0 y_batch=36.58639803
# x_batch=87.0 y_batch=87.28898389
# x_batch=36.0 y_batch=32.46387493
# x_batch=12.0 y_batch=10.78089683
# x_batch=81.0 y_batch=80.7633986
# x_batch=25.0 y_batch=24.61215147
# x_batch=5.0 y_batch=6.963319071
# x_batch=16.0 y_batch=11.23757338
# x_batch=16.0 y_batch=13.53290206
# x_batch=24.0 y_batch=24.60323899
# x_batch=39.0 y_batch=39.40049976
# x_batch=54.0 y_batch=48.43753838
# x_batch=60.0 y_batch=61.69900319
# x_batch=26.0 y_batch=26.92832418
# x_batch=73.0 y_batch=70.4052055
# x_batch=29.0 y_batch=29.34092408
# x_batch=31.0 y_batch=25.30895192
# x_batch=68.0 y_batch=69.02934339
# x_batch=87.0 y_batch=84.99484703
# x_batch=58.0 y_batch=57.04310305
# x_batch=54.0 y_batch=50.5921991
# x_batch=84.0 y_batch=83.02772202
# x_batch=58.0 y_batch=57.05752706
# x_batch=49.0 y_batch=47.95883341
# x_batch=20.0 y_batch=24.34226432
# x_batch=90.0 y_batch=94.68488281
# x_batch=48.0 y_batch=48.03970696
# x_batch=4.0 y_batch=7.08132338
# x_batch=25.0 y_batch=21.99239907
# x_batch=42.0 y_batch=42.33151664
# x_batch=0.0 y_batch=0.329089443
# x_batch=60.0 y_batch=61.92303698
# x_batch=93.0 y_batch=91.17716423
# x_batch=39.0 y_batch=39.45358014
# x_batch=7.0 y_batch=5.996069607
# x_batch=21.0 y_batch=22.59015942
# x_batch=68.0 y_batch=61.18044414
# x_batch=84.0 y_batch=85.02778957
# x_batch=0.0 y_batch=-1.28631089
# x_batch=58.0 y_batch=61.94273962
# x_batch=19.0 y_batch=21.96033347
# x_batch=36.0 y_batch=33.66194193
# x_batch=19.0 y_batch=17.60946242
# x_batch=59.0 y_batch=58.5630564
# x_batch=51.0 y_batch=52.82390762
# x_batch=19.0 y_batch=22.1363481
# x_batch=33.0 y_batch=35.07467353
# x_batch=85.0 y_batch=86.18822311
# x_batch=44.0 y_batch=42.63227697
# x_batch=5.0 y_batch=4.09817744
# x_batch=59.0 y_batch=61.2229864
# x_batch=14.0 y_batch=17.70677576
# x_batch=9.0 y_batch=11.85312574
# x_batch=75.0 y_batch=80.23051695
# x_batch=69.0 y_batch=62.64931741
# x_batch=10.0 y_batch=9.616859804
# x_batch=17.0 y_batch=20.02797699
# x_batch=58.0 y_batch=61.7510743
# x_batch=74.0 y_batch=71.61010303
# x_batch=21.0 y_batch=23.77154623
# ...
# x_batch=72.0 y_batch=74.04682658
# x_batch=5.0 y_batch=1.611947467
# x_batch=71.0 y_batch=70.36836307
# x_batch=54.0 y_batch=52.26831735
# x_batch=84.0 y_batch=83.1286166
# x_batch=42.0 y_batch=43.64765048
# x_batch=54.0 y_batch=49.44785426
# x_batch=74.0 y_batch=72.6356699
# x_batch=54.0 y_batch=52.78130641
# x_batch=53.0 y_batch=57.11195136
# x_batch=78.0 y_batch=79.1050629
# x_batch=97.0 y_batch=101.6228548
# x_batch=49.0 y_batch=53.5825402
# x_batch=71.0 y_batch=68.92139297
# x_batch=48.0 y_batch=46.9666961
# x_batch=51.0 y_batch=51.02642868
# x_batch=89.0 y_batch=85.52073551
# x_batch=99.0 y_batch=99.51685756
# x_batch=93.0 y_batch=94.63911256
# x_batch=49.0 y_batch=46.78357742
# x_batch=18.0 y_batch=21.21321959
# x_batch=65.0 y_batch=58.37266004
# x_batch=83.0 y_batch=87.22059677
# x_batch=100.0 y_batch=102.4967859
# x_batch=41.0 y_batch=43.88314335
# x_batch=52.0 y_batch=53.06655757
# x_batch=29.0 y_batch=26.33464785
# x_batch=97.0 y_batch=98.52008934
# x_batch=7.0 y_batch=9.400497579
# x_batch=51.0 y_batch=52.94026699
# x_batch=58.0 y_batch=53.83020877
# x_batch=50.0 y_batch=45.94511142
# x_batch=67.0 y_batch=65.0132736
# x_batch=89.0 y_batch=86.5069584
# x_batch=76.0 y_batch=75.63280796
# x_batch=35.0 y_batch=36.78035027
# x_batch=99.0 y_batch=100.5328916
# x_batch=31.0 y_batch=29.04466136
# x_batch=52.0 y_batch=51.70352433
# x_batch=11.0 y_batch=9.199954718
# x_batch=66.0 y_batch=71.70015848
# x_batch=50.0 y_batch=49.82634062
# x_batch=39.0 y_batch=37.49971096
# x_batch=60.0 y_batch=53.65084683
# x_batch=35.0 y_batch=33.92561965
# x_batch=53.0 y_batch=49.92639685
# x_batch=14.0 y_batch=8.148154262
# x_batch=49.0 y_batch=49.72359037
# x_batch=16.0 y_batch=16.16712757
# x_batch=76.0 y_batch=75.30033002
# x_batch=13.0 y_batch=9.577368568
# x_batch=51.0 y_batch=48.38088357
# x_batch=70.0 y_batch=72.95331671
# x_batch=98.0 y_batch=92.59573853
# x_batch=86.0 y_batch=88.85523586
# x_batch=100.0 y_batch=99.00361771
# x_batch=46.0 y_batch=45.09439571
# x_batch=51.0 y_batch=46.94362684
# x_batch=50.0 y_batch=48.33449605
# x_batch=91.0 y_batch=94.92329574
# x_batch=48.0 y_batch=47.78165248
# x_batch=81.0 y_batch=81.28960746
# x_batch=38.0 y_batch=37.83155021
# x_batch=40.0 y_batch=39.69185252
# x_batch=79.0 y_batch=76.92664854
# x_batch=96.0 y_batch=88.02990531
# x_batch=60.0 y_batch=56.99178872
# x_batch=70.0 y_batch=72.58929383
# x_batch=44.0 y_batch=44.98103442
# x_batch=11.0 y_batch=11.99017641
# x_batch=6.0 y_batch=1.919513328
# x_batch=5.0 y_batch=1.628826073
# x_batch=72.0 y_batch=66.27746655
# x_batch=55.0 y_batch=57.53887255
# x_batch=95.0 y_batch=94.70291077
# x_batch=41.0 y_batch=41.21469904
# x_batch=25.0 y_batch=25.04169243
# x_batch=1.0 y_batch=3.778209914
# x_batch=55.0 y_batch=50.50711779
# x_batch=4.0 y_batch=9.682408486
# x_batch=48.0 y_batch=48.88147608
# x_batch=55.0 y_batch=54.40348599
# x_batch=75.0 y_batch=71.70233156
# x_batch=68.0 y_batch=69.35848388
# x_batch=100.0 y_batch=99.98491591
# x_batch=25.0 y_batch=26.03323718
# x_batch=75.0 y_batch=75.48910307
# x_batch=34.0 y_batch=36.59623056
# x_batch=38.0 y_batch=40.95102191
# x_batch=92.0 y_batch=86.78316267
# x_batch=21.0 y_batch=15.50701184
# x_batch=88.0 y_batch=85.86077871
# x_batch=75.0 y_batch=79.20610113
# x_batch=76.0 y_batch=80.80643766
# x_batch=44.0 y_batch=48.59717283
# x_batch=10.0 y_batch=13.93415049
# x_batch=21.0 y_batch=27.3051179
# x_batch=16.0 y_batch=14.00226297
# x_batch=32.0 y_batch=33.67416
# x_batch=13.0 y_batch=13.11612884
# x_batch=26.0 y_batch=24.76649193
# x_batch=70.0 y_batch=73.68477876
# x_batch=77.0 y_batch=77.53149541
# x_batch=77.0 y_batch=76.24503196
# x_batch=88.0 y_batch=88.0578931
# x_batch=35.0 y_batch=35.02445799
# x_batch=24.0 y_batch=21.65857739
# x_batch=17.0 y_batch=17.33681562
# x_batch=91.0 y_batch=94.36778957
# x_batch=32.0 y_batch=33.43396307
# x_batch=36.0 y_batch=32.52179399
# x_batch=89.0 y_batch=90.57741298
# x_batch=69.0 y_batch=71.25634126
# x_batch=30.0 y_batch=31.23212856
# x_batch=6.0 y_batch=5.398840061
# x_batch=22.0 y_batch=18.56241391
# x_batch=67.0 y_batch=71.97121038
# x_batch=9.0 y_batch=5.225759566
# x_batch=74.0 y_batch=73.5964342
# x_batch=50.0 y_batch=49.76948983
# x_batch=85.0 y_batch=82.69087513
# x_batch=3.0 y_batch=1.652309089
# x_batch=0.0 y_batch=-3.836652144
# x_batch=59.0 y_batch=62.03811556
# x_batch=62.0 y_batch=61.26514581
# x_batch=17.0 y_batch=13.24991628
# x_batch=90.0 y_batch=88.61672694
# x_batch=23.0 y_batch=21.13655528
# x_batch=19.0 y_batch=23.85017475
# x_batch=93.0 y_batch=92.01203405
# x_batch=14.0 y_batch=10.26712261
# x_batch=58.0 y_batch=54.14681616
# x_batch=87.0 y_batch=87.00645713
# x_batch=37.0 y_batch=37.69447352
# x_batch=20.0 y_batch=19.62278654
# x_batch=35.0 y_batch=34.78561007
# x_batch=63.0 y_batch=62.03190983
# x_batch=56.0 y_batch=52.67003801
# x_batch=62.0 y_batch=58.09031476
# x_batch=98.0 y_batch=97.19448821
# x_batch=90.0 y_batch=90.50155298
# x_batch=51.0 y_batch=50.5123462
# x_batch=93.0 y_batch=94.45211871
# x_batch=22.0 y_batch=21.10794636
# x_batch=38.0 y_batch=37.36298431
# x_batch=13.0 y_batch=10.28574844
# x_batch=98.0 y_batch=96.04932416
# x_batch=99.0 y_batch=100.0953697
# x_batch=31.0 y_batch=30.6063167
# x_batch=94.0 y_batch=96.19000542
# x_batch=73.0 y_batch=71.30828034
# x_batch=37.0 y_batch=34.59311043
# x_batch=23.0 y_batch=19.02332876
# x_batch=11.0 y_batch=10.76669688
# x_batch=88.0 y_batch=90.5799868
# x_batch=47.0 y_batch=48.71787679
# x_batch=79.0 y_batch=78.74139764
# x_batch=91.0 y_batch=85.23492274
# x_batch=71.0 y_batch=71.65789964
# x_batch=10.0 y_batch=8.938990554
# x_batch=39.0 y_batch=39.89606046
# x_batch=92.0 y_batch=91.85091116
# x_batch=99.0 y_batch=99.11200375
# x_batch=28.0 y_batch=26.22196486
# x_batch=32.0 y_batch=33.21584226
# x_batch=32.0 y_batch=35.72392691
# x_batch=75.0 y_batch=76.88604495
# x_batch=99.0 y_batch=99.30874567
# x_batch=27.0 y_batch=25.77161074
# x_batch=64.0 y_batch=67.85169407
# x_batch=98.0 y_batch=98.50371084
# x_batch=38.0 y_batch=31.11331895
# x_batch=46.0 y_batch=45.51171028
# x_batch=13.0 y_batch=12.65537808
# x_batch=96.0 y_batch=95.56065366
# x_batch=9.0 y_batch=9.526431641
# x_batch=34.0 y_batch=36.10893209
# x_batch=49.0 y_batch=46.43628318
# x_batch=1.0 y_batch=-3.83998112
# x_batch=50.0 y_batch=48.97302037
# x_batch=94.0 y_batch=93.25305499
# x_batch=27.0 y_batch=23.47650968
# x_batch=20.0 y_batch=17.13551132
# x_batch=12.0 y_batch=14.55896144
# x_batch=45.0 y_batch=41.53992729
# x_batch=91.0 y_batch=91.64730552
# x_batch=61.0 y_batch=66.16652565
# x_batch=10.0 y_batch=9.230857489
# x_batch=47.0 y_batch=47.41377893
# x_batch=33.0 y_batch=34.76441561
# x_batch=84.0 y_batch=86.10796637
# x_batch=24.0 y_batch=21.81267954
# x_batch=48.0 y_batch=48.89963951
# x_batch=48.0 y_batch=46.78108638
# x_batch=9.0 y_batch=12.91328547
# x_batch=93.0 y_batch=94.55203143
# x_batch=99.0 y_batch=94.97068753
# x_batch=8.0 y_batch=2.379172481
# x_batch=20.0 y_batch=21.47982988
# x_batch=38.0 y_batch=35.79795462
# x_batch=78.0 y_batch=82.0763803
# x_batch=81.0 y_batch=78.87097714
# x_batch=42.0 y_batch=47.2492425
# x_batch=95.0 y_batch=96.18852325
# x_batch=78.0 y_batch=78.38491927
# x_batch=44.0 y_batch=42.94274064
# x_batch=68.0 y_batch=64.43231595
# x_batch=87.0 y_batch=84.21191485
# x_batch=58.0 y_batch=57.3069783
# x_batch=52.0 y_batch=52.52101436
# x_batch=26.0 y_batch=25.7440243
# x_batch=75.0 y_batch=75.42283401
# x_batch=48.0 y_batch=53.62523007
# x_batch=71.0 y_batch=75.14466308
# x_batch=77.0 y_batch=74.12151511
# x_batch=34.0 y_batch=36.24807243
# x_batch=24.0 y_batch=20.21665898
# x_batch=70.0 y_batch=66.94758118
# x_batch=29.0 y_batch=34.07278254
# x_batch=76.0 y_batch=73.13850045
# x_batch=98.0 y_batch=92.85929155
# x_batch=28.0 y_batch=28.36793808
# x_batch=87.0 y_batch=85.59308727
# x_batch=9.0 y_batch=10.68453755
# x_batch=87.0 y_batch=86.10708624
# x_batch=33.0 y_batch=33.22031418
# x_batch=64.0 y_batch=66.09563422
# x_batch=17.0 y_batch=19.30486546
# x_batch=49.0 y_batch=48.84542083
# x_batch=95.0 y_batch=93.73176312
# x_batch=75.0 y_batch=75.45758614
# x_batch=89.0 y_batch=91.24239226
# x_batch=81.0 y_batch=87.15690853
# x_batch=25.0 y_batch=25.53752833
# x_batch=47.0 y_batch=46.06629478
# x_batch=50.0 y_batch=49.65277661
# x_batch=5.0 y_batch=7.382244165
# x_batch=68.0 y_batch=71.11189935
# x_batch=84.0 y_batch=83.50570521
# x_batch=8.0 y_batch=8.791139893
# x_batch=41.0 y_batch=33.30638903
# x_batch=26.0 y_batch=26.40362524
# x_batch=89.0 y_batch=91.72960726
# x_batch=78.0 y_batch=82.53030719
# x_batch=34.0 y_batch=36.67762733
# x_batch=92.0 y_batch=86.98450355
# x_batch=27.0 y_batch=32.34784175
# x_batch=12.0 y_batch=16.78353974
# x_batch=2.0 y_batch=1.576584383
# x_batch=22.0 y_batch=17.4618141
# x_batch=0.0 y_batch=2.116113029
# x_batch=26.0 y_batch=24.34804332
# x_batch=50.0 y_batch=48.29491198
# x_batch=84.0 y_batch=85.52145453
# x_batch=70.0 y_batch=73.71434779
# x_batch=66.0 y_batch=63.15189497
# x_batch=42.0 y_batch=38.46213684
# x_batch=19.0 y_batch=19.47100788
# x_batch=94.0 y_batch=94.07428225
# x_batch=71.0 y_batch=67.92051286
# x_batch=19.0 y_batch=22.58096241
# x_batch=16.0 y_batch=16.01629889
# x_batch=49.0 y_batch=48.43307886
# x_batch=29.0 y_batch=29.6673599
# x_batch=29.0 y_batch=26.65566328
# x_batch=86.0 y_batch=86.28206739
# x_batch=50.0 y_batch=50.82304924
# x_batch=86.0 y_batch=88.57251713
# x_batch=30.0 y_batch=32.59980745
# x_batch=23.0 y_batch=21.02469368
# x_batch=20.0 y_batch=20.72894979
# x_batch=16.0 y_batch=20.38051187
# x_batch=57.0 y_batch=57.25180153
# x_batch=8.0 y_batch=6.967537054
# x_batch=8.0 y_batch=10.240085
# x_batch=62.0 y_batch=64.94841088
# x_batch=55.0 y_batch=55.35893915
# x_batch=30.0 y_batch=31.24365589
# x_batch=86.0 y_batch=90.72048818
# x_batch=62.0 y_batch=58.750127
# x_batch=51.0 y_batch=55.85003198
# x_batch=61.0 y_batch=60.19925869
# x_batch=86.0 y_batch=85.03295412
# x_batch=61.0 y_batch=60.38823085
# x_batch=21.0 y_batch=18.44679787
# x_batch=81.0 y_batch=82.18839247
# x_batch=97.0 y_batch=94.2963344
# x_batch=5.0 y_batch=7.682024586
# x_batch=61.0 y_batch=61.01858089
# x_batch=47.0 y_batch=53.60562216
# x_batch=98.0 y_batch=94.47728801
# x_batch=30.0 y_batch=27.9645947
# x_batch=63.0 y_batch=62.55662585
# x_batch=0.0 y_batch=1.406254414
# x_batch=100.0 y_batch=101.7003412
# x_batch=18.0 y_batch=13.84973988
# x_batch=30.0 y_batch=28.99769315
# x_batch=98.0 y_batch=99.04315693
# x_batch=16.0 y_batch=15.56135514
# x_batch=22.0 y_batch=24.63528393
# x_batch=55.0 y_batch=53.98393374
# x_batch=43.0 y_batch=42.91449728
# x_batch=75.0 y_batch=74.29662112
# x_batch=91.0 y_batch=91.17012883
# x_batch=46.0 y_batch=49.42440876
# x_batch=85.0 y_batch=82.47683519
# x_batch=55.0 y_batch=56.15303953
# x_batch=36.0 y_batch=37.17063131
# x_batch=49.0 y_batch=46.36928662
# x_batch=94.0 y_batch=97.02383456
# x_batch=43.0 y_batch=40.83182104
# x_batch=22.0 y_batch=24.08498313
# x_batch=37.0 y_batch=41.14386358
# x_batch=24.0 y_batch=21.97388066
# x_batch=95.0 y_batch=100.740897
# x_batch=61.0 y_batch=61.19971596
# x_batch=75.0 y_batch=74.39517002
# x_batch=68.0 y_batch=69.04377173
# x_batch=58.0 y_batch=56.68718792
# x_batch=5.0 y_batch=5.860391715
# x_batch=53.0 y_batch=55.72021356
# x_batch=80.0 y_batch=79.22021816
# x_batch=83.0 y_batch=86.30177517
# x_batch=25.0 y_batch=25.26971886
# x_batch=34.0 y_batch=36.33294447
# x_batch=26.0 y_batch=27.65574228
# x_batch=90.0 y_batch=94.79690531
# x_batch=60.0 y_batch=58.67366671
# x_batch=49.0 y_batch=56.15934471
# x_batch=19.0 y_batch=18.40919388
# x_batch=92.0 y_batch=86.26936988
# x_batch=29.0 y_batch=26.59436195
# x_batch=8.0 y_batch=8.452520159
# x_batch=57.0 y_batch=56.18131518
# x_batch=29.0 y_batch=27.65452669
# x_batch=19.0 y_batch=20.87391785
# x_batch=81.0 y_batch=77.83354439
# x_batch=50.0 y_batch=50.01787825
# x_batch=15.0 y_batch=9.290856256
# x_batch=70.0 y_batch=75.0284725
# x_batch=39.0 y_batch=38.3037698
# x_batch=43.0 y_batch=44.70786405
# x_batch=21.0 y_batch=22.51016575
# x_batch=98.0 y_batch=102.4959452
# x_batch=86.0 y_batch=86.76845244
# x_batch=16.0 y_batch=13.89748578
# x_batch=25.0 y_batch=24.81824269
# x_batch=31.0 y_batch=33.94224862
# x_batch=93.0 y_batch=92.26970059
# x_batch=67.0 y_batch=68.73365081
# x_batch=49.0 y_batch=47.38516883
# x_batch=25.0 y_batch=32.37576914
# x_batch=88.0 y_batch=87.67388681
# x_batch=54.0 y_batch=54.57648371
# x_batch=21.0 y_batch=18.06450222
# x_batch=8.0 y_batch=7.896539841
# x_batch=32.0 y_batch=35.00341078
# x_batch=35.0 y_batch=36.72823317
# x_batch=67.0 y_batch=65.84975426
# x_batch=90.0 y_batch=89.59295492
# x_batch=59.0 y_batch=61.69026202
# x_batch=15.0 y_batch=11.60499315
# x_batch=67.0 y_batch=71.0826803
# x_batch=42.0 y_batch=43.71901164
# x_batch=44.0 y_batch=41.57421008
# x_batch=77.0 y_batch=74.25552425
# x_batch=68.0 y_batch=66.28310437
# x_batch=36.0 y_batch=36.62438077
# x_batch=11.0 y_batch=10.32374866
# x_batch=10.0 y_batch=7.156457657
# x_batch=65.0 y_batch=67.88603132
# x_batch=98.0 y_batch=101.1097591
# x_batch=98.0 y_batch=98.6132033
# x_batch=49.0 y_batch=50.19083844
# x_batch=31.0 y_batch=27.83896261
# x_batch=56.0 y_batch=55.9249564
# x_batch=70.0 y_batch=76.47340872
# x_batch=91.0 y_batch=92.05756378
# x_batch=25.0 y_batch=27.35245439
# x_batch=54.0 y_batch=55.32083476
# x_batch=39.0 y_batch=41.39990349
# x_batch=91.0 y_batch=93.59057024
# x_batch=3.0 y_batch=5.297054029
# x_batch=22.0 y_batch=21.01429422
# x_batch=2.0 y_batch=2.267059451
# x_batch=2.0 y_batch=-0.121860502
# x_batch=65.0 y_batch=66.49546208
# x_batch=71.0 y_batch=73.83637687
# x_batch=42.0 y_batch=42.10140878
# x_batch=76.0 y_batch=77.35135732
# x_batch=43.0 y_batch=41.02251779
# x_batch=8.0 y_batch=14.75305272
# x_batch=86.0 y_batch=83.28199022
# x_batch=87.0 y_batch=89.93374342
# x_batch=3.0 y_batch=2.286571686
# x_batch=58.0 y_batch=55.61421297
# x_batch=62.0 y_batch=62.15313408
# x_batch=89.0 y_batch=89.55803528
# x_batch=95.0 y_batch=94.00291863
# x_batch=28.0 y_batch=26.78023848
# x_batch=0.0 y_batch=-0.764537626
# x_batch=1.0 y_batch=0.282866003
# x_batch=49.0 y_batch=44.26800515
# x_batch=21.0 y_batch=19.85174138
# x_batch=46.0 y_batch=47.15960005
# x_batch=11.0 y_batch=8.359366572
# x_batch=89.0 y_batch=92.08157084
# x_batch=37.0 y_batch=41.88734051
# x_batch=29.0 y_batch=30.5413129
# x_batch=44.0 y_batch=46.87654473
# x_batch=96.0 y_batch=96.35659485
# x_batch=16.0 y_batch=17.9170699
# x_batch=74.0 y_batch=71.67949917
# x_batch=35.0 y_batch=32.64997554
# x_batch=42.0 y_batch=39.34482965
# x_batch=16.0 y_batch=17.03401999
# x_batch=56.0 y_batch=52.87524074
# x_batch=18.0 y_batch=15.85414849
# x_batch=100.0 y_batch=108.8716183
# x_batch=54.0 y_batch=49.30477253
# x_batch=92.0 y_batch=89.4749477
# x_batch=63.0 y_batch=63.67348242
# x_batch=81.0 y_batch=83.78410946
# x_batch=73.0 y_batch=73.51136922
# x_batch=48.0 y_batch=46.80297244
# x_batch=1.0 y_batch=5.809946802
# x_batch=85.0 y_batch=85.23027975
# x_batch=14.0 y_batch=10.58213964
# x_batch=25.0 y_batch=21.37698317
# x_batch=45.0 y_batch=46.0537745
# x_batch=98.0 y_batch=95.2389253
# x_batch=97.0 y_batch=94.15149206
# x_batch=58.0 y_batch=54.54868046
# x_batch=93.0 y_batch=87.36260449
# x_batch=88.0 y_batch=88.47741598
# x_batch=89.0 y_batch=84.48045678
# x_batch=47.0 y_batch=48.79647071
# x_batch=6.0 y_batch=10.76675683
# x_batch=34.0 y_batch=30.48882921
# x_batch=30.0 y_batch=29.76846185
# x_batch=16.0 y_batch=13.51574749
# x_batch=86.0 y_batch=86.12955884
# x_batch=40.0 y_batch=43.30022747
# x_batch=52.0 y_batch=51.92110232
# x_batch=15.0 y_batch=16.49185287
# x_batch=4.0 y_batch=7.998073432
# x_batch=95.0 y_batch=97.66689567
# x_batch=99.0 y_batch=89.80545367
# x_batch=35.0 y_batch=38.07166567
# x_batch=58.0 y_batch=60.27852322
# x_batch=10.0 y_batch=6.709195759
# x_batch=16.0 y_batch=18.35488924
# x_batch=53.0 y_batch=56.37058203
# x_batch=58.0 y_batch=62.80064204
# x_batch=42.0 y_batch=41.25155632
# x_batch=24.0 y_batch=19.42637541
# x_batch=84.0 y_batch=82.88935804
# x_batch=64.0 y_batch=63.61364981
# x_batch=12.0 y_batch=11.29627199
# x_batch=61.0 y_batch=60.02274882
# x_batch=75.0 y_batch=72.60339326
# x_batch=15.0 y_batch=11.87964573
# x_batch=100.0 y_batch=100.7012737
# x_batch=43.0 y_batch=45.12420809
# x_batch=13.0 y_batch=14.81106804
# x_batch=48.0 y_batch=48.09368034
# x_batch=45.0 y_batch=42.29145672
# x_batch=52.0 y_batch=52.73389794
# x_batch=34.0 y_batch=36.72396986
# x_batch=30.0 y_batch=28.64535198
# x_batch=65.0 y_batch=62.16675273
# x_batch=100.0 y_batch=95.58459518
# x_batch=67.0 y_batch=66.04325304
# x_batch=99.0 y_batch=99.9566225
# x_batch=45.0 y_batch=46.14941984
# x_batch=87.0 y_batch=89.13754963
# x_batch=73.0 y_batch=69.71787806
# x_batch=9.0 y_batch=12.31736648
# x_batch=81.0 y_batch=78.20296268
# x_batch=72.0 y_batch=71.30995371
# x_batch=81.0 y_batch=81.45544709
# x_batch=58.0 y_batch=58.59500642
# x_batch=93.0 y_batch=94.62509374
# x_batch=82.0 y_batch=88.60376995
# x_batch=66.0 y_batch=63.64868529
# x_batch=97.0 y_batch=94.9752655
# Epoch 4: nan

# %% [markdown]
# **NOTE:** In the last code block, if your loss gradually increased, stayed the same, or return NaN, then go back to the optimizer and lower the learning rate.

# %% [markdown]
# Use the code below to plot the data and the regression line.

# %%
plt.scatter(df.values[:,0], df.values[:,1])
plt.plot(df.values[:,0], weight*df.values[:,0]+bias, 'ro')
plt.show()

# %% [markdown]
# ## Logistic Regression Using MNIST

# %% [markdown]
# Tensorflow provides a convenient interface for MNIST data. This makes it really easy to test your code on a dataset that is commonly used. The code below shows you how to read MNIST images and store the labels as one-hot vectors

# %%
from tensorflow.examples.tutorials.mnist import input_data
MNIST = input_data.read_data_sets("../data/mnist", one_hot = True)
# Out:
# WARNING:tensorflow:From /Users/thchang/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# WARNING:tensorflow:From <ipython-input-33-986c1777d691>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/thchang/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /Users/thchang/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:219: wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /Users/thchang/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ../data/mnist/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /Users/thchang/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ../data/mnist/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/thchang/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting ../data/mnist/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting ../data/mnist/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/thchang/anaconda2/lib/python2.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: __init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# Create placeholders for X and Y.
# * Note that each MNIST image is 28x28. Additionally, the data will already be flattened into a 784 dimensional vector when we input it into the model
# * Each label is 10d - a vector element for every possible digit.
# * Make sure the shapes of the placeholders are defined so a variable number of images and labels can be fed in each batch. *This is what index 0 manages. Just put None instead of a dimension in this piece of the net*

# %%
#TODO: Fill in the dots
X = tf.placeholder (tf.float32, shape=[None, 784], name='X')
YLabel = tf.placeholder (tf.float32, shape=[None,10], name='Y')

# %% [markdown]
# Create a weights variable and a biases variable of the appropriate shapes.
# * Initialize the weights variable from a truncated normal distribution using tf.truncated_normal(...) - this is better than setting weights to zero because it removes symmetry from backpropagation. [Here's a more in depth discussion](https://datascience.stackexchange.com/a/10930)
# * The bias variable should also be set to a small value, such as 0.1. Do this by using tf.constant(...) and inputting the value and the appropriate shape
# * When you multiply the feature vector X and the weights variable, the result should be the same shape as the bias tensor so they can be added

# %%
#TODO: Fill in the dots - Look at page 76
W = tf.Variable (tf.truncated_normal(shape=[784, 10], mean=0.5, stddev=1.0))

b = tf.Variable(tf.convert_to_tensor(np.full([10], 0.1), dtype=tf.float32))
#b = tf.Variable(tf.zeros([10]), name='b')

# %% [markdown]
# Declare the logits as $X \cdot W + b$. Logits are a quantity that will be mapped to a probability with softmax. This is the exact same expression as multi-dimensional linear regression.
# * Make sure to use tf.matmul() when multiplying matrices. Using \* will multiply element wise

# %%
# Logits are quantities that will be mapped with a probabiilty using softmax
y = tf.matmul(X, W) + b

# %% [markdown]
# Compute the entropy using tf.nn.softmax_cross_entropy_with_logits(...). This will apply the softmax function to the logits before calculating the entropy. Compute the loss as the mean over the entropy.

# %%
#TODO: Fill in the dots
entropy = tf.nn.softmax_cross_entropy_with_logits(logits = y, labels = YLabel)
loss = tf.reduce_mean(entropy)
# Out:
# WARNING:tensorflow:From <ipython-input-60-2a42c3eb6869>:2: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# Declare the optimizer as the GradientDescentOptimizer with an appropriate learning rate. *(Hint: Try 0.01).* Set it to minimize the loss.
# * Note: When running the optimizer, if the loss is nan or increasing with each epoch, try decreasing the learning rate

# %%
#TODO: Fill in the dots
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01).minimize(loss)

# %% [markdown]
# Compute the accuracy by:
# * using tf.equal on the predicted label and the true label
# * casting that to a float and computing the mean over all examples

# %%
#TODO: Fill in the dots
Y_pred = tf.nn.softmax(logits)
y_pred_cls = tf.argmax(Y_pred, 1)
y_cls = ...
accuracy = tf.reduce_mean(tf.cast(tf.equal(..., ...), tf.float32))

# %% [markdown]
# Start an Interactive Session and initialize all the global variables.
# * For each epoch, run the optimizer on each X,y pair and sum up the loss over all data points
# * Print the loss after each epoch

# %%
#TODO: Fill in the dots

sess = tf.InteractiveSession()
batch_size = 128
# initialize all the global variables
sess.run(...)
n_batches = (int) (MNIST.train.num_examples/batch_size)
for i in range(25):
    total_loss = 0
    for batch in range(n_batches):
        # iterate through the batches 
        X_batch, y_batch = MNIST.train.next_batch(batch_size)
        o, l = sess.run(...)
        total_loss += l
    print("Epoch {0}; Loss: {1}".format(i, total_loss))

# %% [markdown]
# Run the accuracy by feeding in all the test examples.

# %%
#TODO: Fill in the dots

print("Computing accuracy ...")
X_batch, y_batch = MNIST.test.next_batch(MNIST.test.num_examples)
final_accuracy = sess.run(...)

print ("Accuracy {0}".format(final_accuracy))

# %% [markdown]
# # Basic Feed Forward Network on MNIST
# Here we build a simple fully-connected network for MNIST. The network will have 2 hidden layers:  784 input neurons (28x28 shaped mnist), 2x layers with 256 hidden neurons , and 10 output neurons ( 1 for each digit)

# %% [markdown]
# Create placeholders for X and Y.

# %%
#TODO: Fill in the dots
X = tf.placeholder(...)
Y = tf.placeholder(...)

# %% [markdown]
# Declare each layer in the network and the final logits by:
# * Creating variables for weights and biases of the appropriate sizes
# * Applying ReLu on $X \cdot W + b$
#
# This formulation is nearly the same as the logistic regression setup - except instead of applying softmax on the output of the hidden layers, we apply [relu](https://en.wikipedia.org/wiki/Rectifier_(neural_networks))
#
# Network Configurations:
# * First layer has 784 input features and 256 output features
# * Second layer has 256 input features and 256 output features
# * Third layer has 256 input features and 10 output features

# %%
#TODO: Fill in the dots

W1 = tf.Variable(tf.truncated_normal(...))
b1 = tf.Variable(tf.constant(...))
layer1 = tf.nn.relu(tf.matmul(X, W1) + b1)

W2 = tf.Variable(...)
b2 = tf.Variable(tf.constant(...))
layer2 = tf.nn.relu(...)

W_out = tf.Variable(...)
b_out = tf.Variable(tf.constant(...))
logits = tf.matmul(...) + ...

# %% [markdown]
# Compute the entropy using tf.nn.softmax_cross_entropy_with_logits. This will apply the softmax function to the logits before calculating the entropy. The loss as the mean over the entropy.

# %%
#TODO: Fill in the dots

entropy = tf.nn.softmax_cross_entropy_with_logits(logits = ..., labels=...)
loss = tf.reduce_mean(...)

# %% [markdown]
# Declare the optimizer as the GradientDescentOptimizer with an appropriate learning rate. Set it to minimize the loss.

# %%
#TODO: Fill in the dots

optimizer = ...

# %% [markdown]
# Compute the accuracy by:
# * using tf.equal on the predicted label and the true label
# * casting that to a float and computing the mean over all examples

# %%
#TODO: Fill in the dots

Y_pred = tf.nn.softmax(logits)
y_pred_cls = ...
y_cls = ...
accuracy = tf.reduce_mean(tf.cast(tf.equal(...), tf.float32))

# %% [markdown]
# Start an Interactive Session and initialize all the global variables.
# * For each epoch, run the optimizer on each X,y batch and sum up the loss over all data points
# * Print the loss after each epoch
#
# We set the batch size to 128 and epochs to 25. Feel free to play around with these variables. Additionally, every 5 epochs we calculate validation accuracy

# %%
#TODO: Fill in the dots

batch_size = 128
epochs = 25
sess = tf.InteractiveSession()
sess.run(...)

n_batches = (int) ...
for i in range(epochs):
    total_loss = 0
    for batch in range(n_batches):
        X_batch, y_batch = ...
        o, l = sess.run(...)
        total_loss += l
    print("Epoch {0}: {1}".format(i, total_loss))
    if i % 5 == 0 and i!= 0:
        X_val, y_val = MNIST.validation.next_batch(MNIST.validation.num_examples)
        val_accuracy = sess.run(...)
        print("\tVal Accuracy {0}".format(val_accuracy))

# %% [markdown]
# After training and all validation, you'll want to return your test accuracy

# %%
#TODO: Fill in the dots

print("Computing accuracy ...")
X_batch, y_batch = MNIST.test.next_batch(MNIST.test.num_examples)
final_accuracy = sess.run(...)

print ("Test Accuracy {0}".format(final_accuracy))
